# %% [markdown]
# # Manipulation algorithm
# This notebook will apply Algorithm 1 to a given profile of voters and candidates. A notebook format is used to provide commentary and illustrate step-by-step the process in the algorithm.

# %%
#Key package imports
from itertools import permutations
import spatialGeneration
import itertools
import csv
import copy
import math
import matplotlib.pyplot as plt
import time

# %%
def setup():
    """setup()
    Takes the number of candidates, current voter rankings and coalition size.
    Creates a dictionary with the current votes for each candidate, and a list
    of potential elimination orders."""

    # list of ordered votes that we already know about
    """voter1 = {"A":1, "B": 2, "C": 3, "D": 4}
    voter2 = {"A":3, "B": 1, "C": 2, "D": 4}
    voter3 = {"A":1, "B": 2, "C": 3, "D": 4}
    voting_array = [voter1,voter2,voter3]"""
    
    voting_array = []
    #read csv for list of ordered votes that we already know about
    #with open("Exports/Export1678356411.497025.csv","r",newline='\n') as file:
    #    reader = csv.reader(file, delimiter=',')
    #    candidates = next(reader)
    #    #print(candidates)
    #    number_of_cands = len(candidates)
    #    for row in reader:
            #print(row)
    #        Vote = dict(zip(candidates,[int(i) for i in row]))
    #        voting_array.append(Vote)
            #print(voting_array)
    voting_array = copy.deepcopy(gen_Ranking)
    candidates = copy.deepcopy(gen_Candidates)
    #voting_array.pop(0) #necessary to delete headers
    #print(voting_array)
    candidates_and_votes = tally_votes(voting_array, candidates)

    # potential orders of elimination of candidates
    elimination_orders= []
    # Get permutations of n-1 candidates
    cand = list(candidates_and_votes.keys())
    perms_of_candidates = permutations(cand[0:len(candidates)-1])
    for i in perms_of_candidates:
        x = list(i)+[cand[-1]]
        elimination_orders.append(x)
    #print("orders: ",elimination_orders)
    #print(candidates_and_votes,voting_array)
    return candidates_and_votes, elimination_orders, voting_array, candidates

# %%
def tally_votes(v_array, candidates):
    # the candidates and the number of 1st choice votes they have
    candidates_and_votes = {candidates[i]:0 for i in range(0,len(candidates))}
    #print(candidates_and_votes)
    
    # add each voter's current 1st choice to the voting_array
    #print(voting_array)
    for voter in v_array:
        #print(voter)
        for key in voter:
            if voter[key]==1:
                candidates_and_votes[key]+=1
    return(candidates_and_votes)

# %%
def remove_orders(unsuccesful_start):
    elimination_orders_remove = []
    k = len(unsuccesful_start) 
    copy = elimination_orders.copy()
    for i in copy:
        if i[0:k] == unsuccesful_start:
            elimination_orders.remove(i)

# %%
def check_order(candidates_and_votes, order, col_size, voting_array, candidates):
    coalition_size = copy.deepcopy(col_size)
    voting_array_c = copy.deepcopy(voting_array)
    #print("HERE",candidates_and_votes)
    coalition_votes = []
    coalition_store = []
    dic__coalition_votes = []
    eliminated_candidates = []
    candidates_remaining = copy.deepcopy(candidates)
    for i in range(0,coalition_size):
        coalition_votes.append([])
    count = 1
    # copy of candidates and votes
    variable_votes = dict(candidates_and_votes)
    for i in order:
        eliminated_candidates.append(i)
        for j in order[order.index(i)+1:]:
            # compute votes required for j to beat i
            votes_req = int(variable_votes[i]) - int(variable_votes[j]) + 1
            # check that difference is positive
            if votes_req > 0:
                if len(coalition_votes) >= votes_req: # check if coalition size >= votes required to make j beat i
                    variable_votes[j] += votes_req
                    # decrease the amount of votes we can maniplulate this round
                    for c in range(0,votes_req):
                        coalition_votes[0].append(j)
                        coalition_store.append(coalition_votes[0])
                        coalition_votes.remove(coalition_votes[0])

                else:
                    # coalition was too small
                    remove_orders(eliminated_candidates)
                    #print("Elimination order is impossible", order)
                    return "fail","fail"
                    #return [], ord
        candidates_remaining.remove(i)
        if count <= len(order): # no point in doing the very last step of redistrbuting
            for en, voter in enumerate(voting_array_c):
                # Changes any first preference votes to the next available candidate in their preference order
                if voter[i] == 1:
                    voting_array_c[en] = {key: voter[key]-1 for key in voter}
        
                else:
                    # Eliminate candidate i from everyone elses list   
                    voting_array_c[en][i]=0                            
                    for key, value in voter.items():
                        """
                        print("i:",i," ",type(i),"\n",
                              "voter:",voter," ",type(voter),
                              "key:",key," ",type(key),"\n",
                              "value:",value, " ", type(key))"""
                        if int(value) > int(voter[i]):
                            voting_array_c[en][key] += -1
                count +=1
        #print(coalition_store)
        for b in coalition_store:
            if list(set(b).intersection(set(candidates_remaining))) == []:
                coalition_votes.insert(0,b)
                coalition_store.remove(b)
            # voters in coalitions next spot available to be filled
            
            
    coalition_votes += coalition_store
    #print("Successful Manipulation: ", ord)
    for v in coalition_votes:
        
        back_ord = order[::-1]
        #print("BACK ORD:",back_ord)
        dif = list(sorted(set(back_ord) - set(v), key=order.index))
        #print("V:",v)
        v += dif[::-1]
        #print("V+dif:",v)
        #print("NEW DICT:",{key: value+1 for value, key in enumerate(v)})
        dic__coalition_votes.append({key: value+1 for value, key in enumerate(v)})
        #print(order)
        #print({key: value+1 for value, key in enumerate(v)})
    return dic__coalition_votes, order

# %%
def check_manipulation(votes, k, candidates):
    all_votes = votes
    #print("CHECK MANIPULATION OF: ")
    # loop over number of eliminations (n-1 candidates)
    for i in range(0,k-1):
        #print(candidates)
        c_and_v = tally_votes(all_votes, candidates)
        #print("\n c_and_v: ",c_and_v)
        # there can't be ties by construction 
        # needs changing to elimate all candidates with votes = 0 / minimum, and change to while loop (while not just one candidate left with none-zero votes - what if tie?)
        if i == 0:
            elim_cand = min(c_and_v, key=c_and_v.get) #get candidate with least 1st choice votess
        else:
            elim_cand = min(x for x in c_and_v if  c_and_v[x] != 0)
        for en, vote_dict in enumerate(all_votes):
            #print("before", vote_dict)
            #print(elim_cand)
            # Changes any first preference votes to the next available candidate in their preference order
            if vote_dict[elim_cand] == 1:
                all_votes[en] = {key: vote_dict[key]-1 for key in vote_dict}
                all_votes[en].pop(elim_cand)
            else:
                # Eliminate candidate i from everyone elses list
                #all_votes[en][elim_cand] = 0
                for key, value in vote_dict.items():
                    if value > vote_dict[elim_cand]:
                        all_votes[en][key] += -1
                all_votes[en].pop(elim_cand)
           # print("after", all_votes[en])
        candidates.remove(elim_cand)
    #print("CANDIDATES",candidates)
    c_and_v = tally_votes(all_votes, candidates)
    #print("\n c_and_v: ",c_and_v)  
    #print(c_and_v,"\n")

    return (max(c_and_v, key=c_and_v.get))

# %%
#setup()

# %%
#coalition_array = []
#candidates_and_votes, elimination_orders, voting_array,candidates = setup()
#coalition_size = 2000

#for order in elimination_orders:
#    a,b = check_order(candidates_and_votes, order, coalition_size, voting_array,candidates)
#    #print("a: ",a)
#    #print("b: ",b)
#    #coalition_array.append([a,b])
#    if b != "fail":
#        y, yy, yyy,yyyy = setup()
#        check_votes = yyy + a
#       winner = check_manipulation(check_votes,len(yyyy),yyyy)
#        print(b, winner)

# %%
#gen_Ranking,gen_Candidates = spatialGeneration.returnRankings(5,100)

# %% [markdown]
# # Varying $\mathcal{K}$

# %%
gen_Ranking, gen_Candidates = spatialGeneration.returnRankings(5,100)

# %%
candidates_and_votes, elimination_orders, va, candidates = setup()
#coalition_size = 490
#MR = 0
def Cal_MR_K(col):
    MR = 0
    candidates_and_votes, elimination_orders, va, candidates = setup()
    for order in elimination_orders:
        a,b = check_order(candidates_and_votes, order, col, va, gen_Candidates)
        if a != "fail":
            MR += 1
    return MR/(math.factorial(len(gen_Candidates)-1))

# %%
print(math.factorial(len(gen_Candidates)-1))

store = []
for r in range(0,150):
    #candidates_and_votes, elimination_orders, va, candidates = setup()
    store.append(Cal_MR_K(r))
#print(elimination_orders)
plt.plot(range(0,150),store)
plt.ylabel("$MR$ rate")
plt.xlabel("$\mathcal{K}$ (coalition size)")
plt.title("Ratio of possible elimination orders in which $c^*$ wins")
plt.show()
# Out:
# 24

# %%
START = time.time()
stores = []
runs=20
for j in range(0,runs):
    print(j)
    gen_Ranking, gen_Candidates = spatialGeneration.returnRankings(5,100)
    print("Generation successful. Time elapsed",round(time.time()-START,1))
    candidates_and_votes, elimination_orders, va, candidates = setup()
    def Cal_MR_K(col):
        MR = 0
        candidates_and_votes, elimination_orders, va, candidates = setup()
        for order in elimination_orders:
            a,b = check_order(candidates_and_votes, order, col, va, gen_Candidates)
            if a != "fail":
                MR += 1
        return MR/(math.factorial(len(gen_Candidates)-1))

    store = []
    for r in range(0,150):
        #candidates_and_votes, elimination_orders, va, candidates = setup()
        if r%3==0:
            store.append(Cal_MR_K(r))
            #print("Run: ",j,"of",runs, "k: ",r, "Time elapsed: ", round(time.time()-START,1))
        else:
            store.append(store[-1])
    
    
    stores.append(store)
    plt.plot(range(0,150),store)
    
plt.ylabel("$MR$ rate")
plt.xlabel("$\mathcal{K}$ (coalition size)")
plt.title("Ratio of possible elimination orders in which $c^*$ wins")
plt.show()
# Out:
# 0
# Generation successful. Time elapsed 0.1
# 1
# Generation successful. Time elapsed 1.0
# 2
# Generation successful. Time elapsed 2.0
# 3
# Generation successful. Time elapsed 3.0
# 4
# Generation successful. Time elapsed 4.0
# 5
# Generation successful. Time elapsed 5.0
# 6
# Generation successful. Time elapsed 6.0
# 7
# Generation successful. Time elapsed 6.9
# 8
# Generation successful. Time elapsed 7.9
# 9
# Generation successful. Time elapsed 8.8
# 10
# Generation successful. Time elapsed 9.8
# 11
# Generation successful. Time elapsed 10.7
# 12
# Generation successful. Time elapsed 11.7
# 13
# Generation successful. Time elapsed 12.6
# 14
# Generation successful. Time elapsed 13.6
# 15
# Generation successful. Time elapsed 14.6
# 16
# Generation successful. Time elapsed 15.6
# 17
# Generation successful. Time elapsed 16.5
# 18
# Generation successful. Time elapsed 17.5
# 19
# Generation successful. Time elapsed 18.5

# %%
def writeCsv():
    for k in range(13):
        csv_file = "Exports/C9V100/C9V100_"+str(k)+".csv"
        with open(csv_file, 'w',newline='') as csvfile:
            writer = csv.writer(csvfile)
            writer.writerow(stores[k])

# %%
for i in range(0,13):
    plt.plot(range(0,150),stores[i])    
plt.ylabel("$MR$ rate")
plt.xlabel("$\mathcal{K}$ (coalition size)")
plt.title("Ratio of possible elimination orders in which $c^*$ wins")
plt.show()

# %% [markdown]
# # Varying $\mathcal{V}$

# %%
#Successively pop elements from the voter-list, gen_Ranking 

voters = 100
K=int(0.6*voters)
runs=20
START = time.time()

for i in range(runs):
    stores = []

    gen_Ranking, gen_Candidates = spatialGeneration.returnRankings(7,voters)
    print("Generation",i," successful. Time elapsed",round(time.time()-START,1))

    num_voters = len(gen_Ranking)


    store = []

    for k in range(0,int(num_voters*0.9)):
        gen_Ranking.pop(0)
        if k%1==0:
            def Cal_MR_K(col):
                MR = 0
                candidates_and_votes, elimination_orders, va, candidates = setup()
                for order in elimination_orders:
                    a,b = check_order(candidates_and_votes, order, col, va, gen_Candidates)
                    if a != "fail":
                        MR += 1
                return MR/(math.factorial(len(gen_Candidates)-1))
            store.append(Cal_MR_K(K))
            print("Run: ",k,"of",int(num_voters*0.9), "Time elapsed: ", round(time.time()-START,1))
        else:
            store.append(store[-1])

    
    store.reverse
    plt.plot(range(int(num_voters*0.1),num_voters),store[::-1])#reverse array so V and MR line up, as we popped going backwards
    stores.append(store)
plt.ylabel("$MR$ rate")
plt.xlabel("$|\mathcal{V}|$ (number of votes)")
plt.title("Ratio of possible elimination orders in which $c^*$ wins")
plt.show()
# Out:
# Generation 0  successful. Time elapsed 5.5
# Run:  0 of 9000 Time elapsed:  117.9
# Run:  300 of 9000 Time elapsed:  227.4
# Run:  600 of 9000 Time elapsed:  334.3
# Run:  900 of 9000 Time elapsed:  439.2
# Run:  1200 of 9000 Time elapsed:  539.2
# Run:  1500 of 9000 Time elapsed:  636.3
# Run:  1800 of 9000 Time elapsed:  728.8
# Run:  2100 of 9000 Time elapsed:  817.6
# Run:  2400 of 9000 Time elapsed:  905.2
# Run:  2700 of 9000 Time elapsed:  992.1
# Run:  3000 of 9000 Time elapsed:  1075.8
# Run:  3300 of 9000 Time elapsed:  1155.9
# Run:  3600 of 9000 Time elapsed:  1233.5
# Run:  3900 of 9000 Time elapsed:  1308.3
# Run:  4200 of 9000 Time elapsed:  1377.6
# Run:  4500 of 9000 Time elapsed:  1442.8
# Run:  4800 of 9000 Time elapsed:  1505.3
# Run:  5100 of 9000 Time elapsed:  1565.1
# Run:  5400 of 9000 Time elapsed:  1624.0
# Run:  5700 of 9000 Time elapsed:  1679.7
# Run:  6000 of 9000 Time elapsed:  1732.7
# Run:  6300 of 9000 Time elapsed:  1782.9
# Run:  6600 of 9000 Time elapsed:  1829.6
# Run:  6900 of 9000 Time elapsed:  1873.4
# Run:  7200 of 9000 Time elapsed:  1914.2
# Run:  7500 of 9000 Time elapsed:  1950.1
# Run:  7800 of 9000 Time elapsed:  1983.4
# Run:  8100 of 9000 Time elapsed:  2014.0
# Run:  8400 of 9000 Time elapsed:  2041.5
# Run:  8700 of 9000 Time elapsed:  2066.4
# Generation 1  successful. Time elapsed 2071.9
# Run:  0 of 9000 Time elapsed:  2163.7
# Run:  300 of 9000 Time elapsed:  2253.8
# Run:  600 of 9000 Time elapsed:  2344.2
# Run:  900 of 9000 Time elapsed:  2440.5
# Run:  1200 of 9000 Time elapsed:  2534.1
# Run:  1500 of 9000 Time elapsed:  2626.7
# Run:  1800 of 9000 Time elapsed:  2719.3
# Run:  2100 of 9000 Time elapsed:  2808.8
# Run:  2400 of 9000 Time elapsed:  2900.3
# Run:  2700 of 9000 Time elapsed:  2988.6
# Run:  3000 of 9000 Time elapsed:  3073.8
# Run:  3300 of 9000 Time elapsed:  3176.8
# Run:  3600 of 9000 Time elapsed:  3275.8
# Run:  3900 of 9000 Time elapsed:  3370.7
# Run:  4200 of 9000 Time elapsed:  3464.5
# Run:  4500 of 9000 Time elapsed:  3554.4
# Run:  4800 of 9000 Time elapsed:  3640.1
# Run:  5100 of 9000 Time elapsed:  3721.4
# Run:  5400 of 9000 Time elapsed:  3798.4
# Run:  5700 of 9000 Time elapsed:  3871.3
# Run:  6000 of 9000 Time elapsed:  3939.5
# Run:  6300 of 9000 Time elapsed:  4001.8
# Run:  6600 of 9000 Time elapsed:  4058.7
# Run:  6900 of 9000 Time elapsed:  4111.6
# Run:  7200 of 9000 Time elapsed:  4160.9
# Run:  7500 of 9000 Time elapsed:  4205.7
# Run:  7800 of 9000 Time elapsed:  4247.3
# Run:  8100 of 9000 Time elapsed:  4284.9
# Run:  8400 of 9000 Time elapsed:  4318.6
# Run:  8700 of 9000 Time elapsed:  4348.2
# Generation 2  successful. Time elapsed 4353.6
# Run:  0 of 9000 Time elapsed:  4454.4
# Run:  300 of 9000 Time elapsed:  4554.2
# Run:  600 of 9000 Time elapsed:  4651.2
# Run:  900 of 9000 Time elapsed:  4745.2
# Run:  1200 of 9000 Time elapsed:  4836.5
# Run:  1500 of 9000 Time elapsed:  4925.0
# Run:  1800 of 9000 Time elapsed:  5009.0
# Run:  2100 of 9000 Time elapsed:  5089.0
# Run:  2400 of 9000 Time elapsed:  5166.5
# Run:  2700 of 9000 Time elapsed:  5243.4
# Run:  3000 of 9000 Time elapsed:  5318.2
# Run:  3300 of 9000 Time elapsed:  5390.7
# Run:  3600 of 9000 Time elapsed:  5460.3
# Run:  3900 of 9000 Time elapsed:  5527.3
# Run:  4200 of 9000 Time elapsed:  5591.8
# Run:  4500 of 9000 Time elapsed:  5654.0
# Run:  4800 of 9000 Time elapsed:  5713.1
# Run:  5100 of 9000 Time elapsed:  5769.3
# Run:  5400 of 9000 Time elapsed:  5821.8
# Run:  5700 of 9000 Time elapsed:  5870.6
# Run:  6000 of 9000 Time elapsed:  5916.8
# Run:  6300 of 9000 Time elapsed:  5960.0
# Run:  6600 of 9000 Time elapsed:  6000.8
# Run:  6900 of 9000 Time elapsed:  6039.6
# Run:  7200 of 9000 Time elapsed:  6076.8
# Run:  7500 of 9000 Time elapsed:  6111.3
# Run:  7800 of 9000 Time elapsed:  6143.3
# Run:  8100 of 9000 Time elapsed:  6172.5
# Run:  8400 of 9000 Time elapsed:  6199.2
# Run:  8700 of 9000 Time elapsed:  6223.4
# Generation 3  successful. Time elapsed 6229.0
# Run:  0 of 9000 Time elapsed:  6329.0
# Run:  300 of 9000 Time elapsed:  6429.2
# Run:  600 of 9000 Time elapsed:  6527.8
# Run:  900 of 9000 Time elapsed:  6626.6
# Run:  1200 of 9000 Time elapsed:  6720.0
# Run:  1500 of 9000 Time elapsed:  6812.6
# Run:  1800 of 9000 Time elapsed:  6905.5
# Run:  2100 of 9000 Time elapsed:  7001.0
# Run:  2400 of 9000 Time elapsed:  7102.6
# Run:  2700 of 9000 Time elapsed:  7203.9
# Run:  3000 of 9000 Time elapsed:  7302.1
# Run:  3300 of 9000 Time elapsed:  7398.8
# Run:  3600 of 9000 Time elapsed:  7503.1
# Run:  3900 of 9000 Time elapsed:  7598.5
# Run:  4200 of 9000 Time elapsed:  7689.6
# Run:  4500 of 9000 Time elapsed:  7776.8
# Run:  4800 of 9000 Time elapsed:  7860.0
# Run:  5100 of 9000 Time elapsed:  7938.9
# Run:  5400 of 9000 Time elapsed:  8013.4
# Run:  5700 of 9000 Time elapsed:  8083.8
# Run:  6000 of 9000 Time elapsed:  8150.0
# Run:  6300 of 9000 Time elapsed:  8215.0
# Run:  6600 of 9000 Time elapsed:  8275.7
# Run:  6900 of 9000 Time elapsed:  8331.8
# Run:  7200 of 9000 Time elapsed:  8383.8
# Run:  7500 of 9000 Time elapsed:  8431.1
# Run:  7800 of 9000 Time elapsed:  8474.2
# Run:  8100 of 9000 Time elapsed:  8513.4
# Run:  8400 of 9000 Time elapsed:  8548.3
# Run:  8700 of 9000 Time elapsed:  8579.6
# Generation 4  successful. Time elapsed 8585.2
# Run:  0 of 9000 Time elapsed:  8690.4
# Run:  300 of 9000 Time elapsed:  8792.3
# Run:  600 of 9000 Time elapsed:  8892.6
# Run:  900 of 9000 Time elapsed:  8994.6
# Run:  1200 of 9000 Time elapsed:  9096.9
# Run:  1500 of 9000 Time elapsed:  9198.4
# Run:  1800 of 9000 Time elapsed:  9306.1
# Run:  2100 of 9000 Time elapsed:  9411.1
# Run:  2400 of 9000 Time elapsed:  9514.9
# Run:  2700 of 9000 Time elapsed:  9613.2
# Run:  3000 of 9000 Time elapsed:  9718.0
# Run:  3300 of 9000 Time elapsed:  9822.1
# Run:  3600 of 9000 Time elapsed:  9923.2
# Run:  3900 of 9000 Time elapsed:  10020.2
# Run:  4200 of 9000 Time elapsed:  10113.0
# Run:  4500 of 9000 Time elapsed:  10201.4
# Run:  4800 of 9000 Time elapsed:  10285.1
# Run:  5100 of 9000 Time elapsed:  10363.9
# Run:  5400 of 9000 Time elapsed:  10437.1
# Run:  5700 of 9000 Time elapsed:  10505.6
# Run:  6000 of 9000 Time elapsed:  10570.2
# Run:  6300 of 9000 Time elapsed:  10630.1
# Run:  6600 of 9000 Time elapsed:  10686.5
# Run:  6900 of 9000 Time elapsed:  10738.7
# Run:  7200 of 9000 Time elapsed:  10787.0
# Run:  7500 of 9000 Time elapsed:  10831.8
# Run:  7800 of 9000 Time elapsed:  10872.1
# Run:  8100 of 9000 Time elapsed:  10908.1
# Run:  8400 of 9000 Time elapsed:  10940.8
# Run:  8700 of 9000 Time elapsed:  10969.0
# Generation 5  successful. Time elapsed 10974.7
# Run:  0 of 9000 Time elapsed:  11079.9
# Run:  300 of 9000 Time elapsed:  11185.1
# Run:  600 of 9000 Time elapsed:  11290.4
# Run:  900 of 9000 Time elapsed:  11394.1
# Run:  1200 of 9000 Time elapsed:  11497.2
# Run:  1500 of 9000 Time elapsed:  11596.0
# Run:  1800 of 9000 Time elapsed:  11691.7
# Run:  2100 of 9000 Time elapsed:  11792.2
# Run:  2400 of 9000 Time elapsed:  11889.7
# Run:  2700 of 9000 Time elapsed:  11983.8
# Run:  3000 of 9000 Time elapsed:  12076.3
# Run:  3300 of 9000 Time elapsed:  12173.9
# Run:  3600 of 9000 Time elapsed:  12267.3
# Run:  3900 of 9000 Time elapsed:  12354.2
# Run:  4200 of 9000 Time elapsed:  12436.4
# Run:  4500 of 9000 Time elapsed:  12515.2
# Run:  4800 of 9000 Time elapsed:  12593.7
# Run:  5100 of 9000 Time elapsed:  12668.6
# Run:  5400 of 9000 Time elapsed:  12739.1
# Run:  5700 of 9000 Time elapsed:  12804.7
# Run:  6000 of 9000 Time elapsed:  12866.7
# Run:  6300 of 9000 Time elapsed:  12924.4
# Run:  6600 of 9000 Time elapsed:  12978.6
# Run:  6900 of 9000 Time elapsed:  13028.7
# Run:  7200 of 9000 Time elapsed:  13075.0
# Run:  7500 of 9000 Time elapsed:  13117.4
# Run:  7800 of 9000 Time elapsed:  13154.8
# Run:  8100 of 9000 Time elapsed:  13188.8
# Run:  8400 of 9000 Time elapsed:  13219.6
# Run:  8700 of 9000 Time elapsed:  13246.8
# Generation 6  successful. Time elapsed 13252.2
# Run:  0 of 9000 Time elapsed:  13348.4
# Run:  300 of 9000 Time elapsed:  13446.5
# Run:  600 of 9000 Time elapsed:  13544.5
# Run:  900 of 9000 Time elapsed:  13640.1
# Run:  1200 of 9000 Time elapsed:  13733.1
# Run:  1500 of 9000 Time elapsed:  13824.0
# Run:  1800 of 9000 Time elapsed:  13913.4
# Run:  2100 of 9000 Time elapsed:  14001.5
# Run:  2400 of 9000 Time elapsed:  14084.7
# Run:  2700 of 9000 Time elapsed:  14166.5
# Run:  3000 of 9000 Time elapsed:  14247.2
# Run:  3300 of 9000 Time elapsed:  14327.2
# Run:  3600 of 9000 Time elapsed:  14406.6
# Run:  3900 of 9000 Time elapsed:  14486.8
# Run:  4200 of 9000 Time elapsed:  14567.2
# Run:  4500 of 9000 Time elapsed:  14645.3
# Run:  4800 of 9000 Time elapsed:  14722.1
# Run:  5100 of 9000 Time elapsed:  14801.1
# Run:  5400 of 9000 Time elapsed:  14878.4
# Run:  5700 of 9000 Time elapsed:  14953.3
# Run:  6000 of 9000 Time elapsed:  15022.5
# Run:  6300 of 9000 Time elapsed:  15095.1
# Run:  6600 of 9000 Time elapsed:  15161.3
# Run:  6900 of 9000 Time elapsed:  15222.4
# Run:  7200 of 9000 Time elapsed:  15281.5
# Run:  7500 of 9000 Time elapsed:  15335.5
# Run:  7800 of 9000 Time elapsed:  15384.0
# Run:  8100 of 9000 Time elapsed:  15427.4
# Run:  8400 of 9000 Time elapsed:  15465.8
# Run:  8700 of 9000 Time elapsed:  15499.7
# Generation 7  successful. Time elapsed 15505.3
# Run:  0 of 9000 Time elapsed:  15593.1
# Run:  300 of 9000 Time elapsed:  15679.5
# Run:  600 of 9000 Time elapsed:  15764.2
# Run:  900 of 9000 Time elapsed:  15846.7
# Run:  1200 of 9000 Time elapsed:  15925.2
# Run:  1500 of 9000 Time elapsed:  16001.7
# Run:  1800 of 9000 Time elapsed:  16077.6
# Run:  2100 of 9000 Time elapsed:  16156.2
# Run:  2400 of 9000 Time elapsed:  16237.2
# Run:  2700 of 9000 Time elapsed:  16319.0
# Run:  3000 of 9000 Time elapsed:  16398.6
# Run:  3300 of 9000 Time elapsed:  16476.2
# Run:  3600 of 9000 Time elapsed:  16550.6
# Run:  3900 of 9000 Time elapsed:  16623.8
# Run:  4200 of 9000 Time elapsed:  16700.4
# Run:  4500 of 9000 Time elapsed:  16774.4
# Run:  4800 of 9000 Time elapsed:  16851.9
# Run:  5100 of 9000 Time elapsed:  16927.0
# Run:  5400 of 9000 Time elapsed:  17000.8
# Run:  5700 of 9000 Time elapsed:  17072.7
# Run:  6000 of 9000 Time elapsed:  17150.0
# Run:  6300 of 9000 Time elapsed:  17222.5
# Run:  6600 of 9000 Time elapsed:  17291.6
# Run:  6900 of 9000 Time elapsed:  17365.4
# Run:  7200 of 9000 Time elapsed:  17432.5
# Run:  7500 of 9000 Time elapsed:  17493.8
# Run:  7800 of 9000 Time elapsed:  17546.9
# Run:  8100 of 9000 Time elapsed:  17593.8
# Run:  8400 of 9000 Time elapsed:  17634.9
# Run:  8700 of 9000 Time elapsed:  17670.1
# Generation 8  successful. Time elapsed 17675.5
# Run:  0 of 9000 Time elapsed:  17764.3
# Run:  300 of 9000 Time elapsed:  17854.8
# Run:  600 of 9000 Time elapsed:  17943.0
# Run:  900 of 9000 Time elapsed:  18029.2
# Run:  1200 of 9000 Time elapsed:  18114.5
# Run:  1500 of 9000 Time elapsed:  18204.0
# Run:  1800 of 9000 Time elapsed:  18292.3
# Run:  2100 of 9000 Time elapsed:  18377.6
# Run:  2400 of 9000 Time elapsed:  18460.3
# Run:  2700 of 9000 Time elapsed:  18541.4
# Run:  3000 of 9000 Time elapsed:  18620.7
# Run:  3300 of 9000 Time elapsed:  18699.9
# Run:  3600 of 9000 Time elapsed:  18777.7
# Run:  3900 of 9000 Time elapsed:  18853.0
# Run:  4200 of 9000 Time elapsed:  18926.6
# Run:  4500 of 9000 Time elapsed:  18998.9
# Run:  4800 of 9000 Time elapsed:  19070.5
# Run:  5100 of 9000 Time elapsed:  19145.4
# Run:  5400 of 9000 Time elapsed:  19219.5
# Run:  5700 of 9000 Time elapsed:  19292.1
# Run:  6000 of 9000 Time elapsed:  19363.5
# Run:  6300 of 9000 Time elapsed:  19436.5
# Run:  6600 of 9000 Time elapsed:  19507.0
# Run:  6900 of 9000 Time elapsed:  19582.8
# Run:  7200 of 9000 Time elapsed:  19652.2
# Run:  7500 of 9000 Time elapsed:  19715.9
# Run:  7800 of 9000 Time elapsed:  19772.8
# Run:  8100 of 9000 Time elapsed:  19823.6
# Run:  8400 of 9000 Time elapsed:  19868.8
# Run:  8700 of 9000 Time elapsed:  19906.9
# Generation 9  successful. Time elapsed 19912.5
# Run:  0 of 9000 Time elapsed:  20011.7
# Run:  300 of 9000 Time elapsed:  20109.1
# Run:  600 of 9000 Time elapsed:  20205.2
# Run:  900 of 9000 Time elapsed:  20300.0
# Run:  1200 of 9000 Time elapsed:  20398.8
# Run:  1500 of 9000 Time elapsed:  20494.9
# Run:  1800 of 9000 Time elapsed:  20590.7
# Run:  2100 of 9000 Time elapsed:  20691.1
# Run:  2400 of 9000 Time elapsed:  20788.0
# Run:  2700 of 9000 Time elapsed:  20883.4
# Run:  3000 of 9000 Time elapsed:  20977.4
# Run:  3300 of 9000 Time elapsed:  21069.4
# Run:  3600 of 9000 Time elapsed:  21164.9
# Run:  3900 of 9000 Time elapsed:  21253.9
# Run:  4200 of 9000 Time elapsed:  21338.5
# Run:  4500 of 9000 Time elapsed:  21421.2
# Run:  4800 of 9000 Time elapsed:  21510.4
# Run:  5100 of 9000 Time elapsed:  21595.3
# Run:  5400 of 9000 Time elapsed:  21675.4
# Run:  5700 of 9000 Time elapsed:  21751.0
# Run:  6000 of 9000 Time elapsed:  21824.6
# Run:  6300 of 9000 Time elapsed:  21894.3
# Run:  6600 of 9000 Time elapsed:  21959.8
# Run:  6900 of 9000 Time elapsed:  22020.6
# Run:  7200 of 9000 Time elapsed:  22075.8
# Run:  7500 of 9000 Time elapsed:  22125.7
# Run:  7800 of 9000 Time elapsed:  22171.2
# Run:  8100 of 9000 Time elapsed:  22212.2
# Run:  8400 of 9000 Time elapsed:  22247.9
# Run:  8700 of 9000 Time elapsed:  22279.4
# Generation 10  successful. Time elapsed 22285.0
# Run:  0 of 9000 Time elapsed:  22388.3
# Run:  300 of 9000 Time elapsed:  22486.9
# Run:  600 of 9000 Time elapsed:  22585.4
# Run:  900 of 9000 Time elapsed:  22684.8
# Run:  1200 of 9000 Time elapsed:  22783.2
# Run:  1500 of 9000 Time elapsed:  22881.3
# Run:  1800 of 9000 Time elapsed:  22977.4
# Run:  2100 of 9000 Time elapsed:  23073.1
# Run:  2400 of 9000 Time elapsed:  23166.5
# Run:  2700 of 9000 Time elapsed:  23255.2
# Run:  3000 of 9000 Time elapsed:  23343.2
# Run:  3300 of 9000 Time elapsed:  23434.6
# Run:  3600 of 9000 Time elapsed:  23524.9
# Run:  3900 of 9000 Time elapsed:  23616.1
# Run:  4200 of 9000 Time elapsed:  23705.6
# Run:  4500 of 9000 Time elapsed:  23790.4
# Run:  4800 of 9000 Time elapsed:  23881.4
# Run:  5100 of 9000 Time elapsed:  23965.3
# Run:  5400 of 9000 Time elapsed:  24042.5
# Run:  5700 of 9000 Time elapsed:  24115.1
# Run:  6000 of 9000 Time elapsed:  24182.9
# Run:  6300 of 9000 Time elapsed:  24249.0
# Run:  6600 of 9000 Time elapsed:  24311.3
# Run:  6900 of 9000 Time elapsed:  24368.8
# Run:  7200 of 9000 Time elapsed:  24421.8
# Run:  7500 of 9000 Time elapsed:  24469.8
# Run:  7800 of 9000 Time elapsed:  24513.7
# Run:  8100 of 9000 Time elapsed:  24552.6
# Run:  8400 of 9000 Time elapsed:  24587.6
# Run:  8700 of 9000 Time elapsed:  24618.7
# Generation 11  successful. Time elapsed 24624.4
# Run:  0 of 9000 Time elapsed:  24728.1
# Run:  300 of 9000 Time elapsed:  24830.2
# Run:  600 of 9000 Time elapsed:  24930.3
# Run:  900 of 9000 Time elapsed:  25027.8
# Run:  1200 of 9000 Time elapsed:  25122.8
# Run:  1500 of 9000 Time elapsed:  25225.1
# Run:  1800 of 9000 Time elapsed:  25324.9
# Run:  2100 of 9000 Time elapsed:  25424.8
# Run:  2400 of 9000 Time elapsed:  25534.9
# Run:  2700 of 9000 Time elapsed:  25640.5
# Run:  3000 of 9000 Time elapsed:  25741.9
# Run:  3300 of 9000 Time elapsed:  25839.3
# Run:  3600 of 9000 Time elapsed:  25931.3
# Run:  3900 of 9000 Time elapsed:  26017.3
# Run:  4200 of 9000 Time elapsed:  26099.0
# Run:  4500 of 9000 Time elapsed:  26180.5
# Run:  4800 of 9000 Time elapsed:  26258.0
# Run:  5100 of 9000 Time elapsed:  26332.0
# Run:  5400 of 9000 Time elapsed:  26401.7
# Run:  5700 of 9000 Time elapsed:  26467.9
# Run:  6000 of 9000 Time elapsed:  26530.4
# Run:  6300 of 9000 Time elapsed:  26588.8
# Run:  6600 of 9000 Time elapsed:  26643.3
# Run:  6900 of 9000 Time elapsed:  26693.8
# Run:  7200 of 9000 Time elapsed:  26739.0
# Run:  7500 of 9000 Time elapsed:  26780.2
# Run:  7800 of 9000 Time elapsed:  26818.1
# Run:  8100 of 9000 Time elapsed:  26852.6
# Run:  8400 of 9000 Time elapsed:  26883.5
# Run:  8700 of 9000 Time elapsed:  26910.3
# Generation 12  successful. Time elapsed 26915.7
# Run:  0 of 9000 Time elapsed:  27018.1
# Run:  300 of 9000 Time elapsed:  27119.7
# Run:  600 of 9000 Time elapsed:  27219.8
# Run:  900 of 9000 Time elapsed:  27318.0
# Run:  1200 of 9000 Time elapsed:  27414.2
# Run:  1500 of 9000 Time elapsed:  27507.5
# Run:  1800 of 9000 Time elapsed:  27604.1
# Run:  2100 of 9000 Time elapsed:  27697.8
# Run:  2400 of 9000 Time elapsed:  27790.5
# Run:  2700 of 9000 Time elapsed:  27886.4
# Run:  3000 of 9000 Time elapsed:  27979.2
# Run:  3300 of 9000 Time elapsed:  28070.2
# Run:  3600 of 9000 Time elapsed:  28158.0
# Run:  3900 of 9000 Time elapsed:  28253.6
# Run:  4200 of 9000 Time elapsed:  28345.0
# Run:  4500 of 9000 Time elapsed:  28430.6
# Run:  4800 of 9000 Time elapsed:  28510.0
# Run:  5100 of 9000 Time elapsed:  28585.3
# Run:  5400 of 9000 Time elapsed:  28656.7
# Run:  5700 of 9000 Time elapsed:  28726.7
# Run:  6000 of 9000 Time elapsed:  28793.8
# Run:  6300 of 9000 Time elapsed:  28856.5
# Run:  6600 of 9000 Time elapsed:  28915.0
# Run:  6900 of 9000 Time elapsed:  28969.9
# Run:  7200 of 9000 Time elapsed:  29020.9
# Run:  7500 of 9000 Time elapsed:  29067.0
# Run:  7800 of 9000 Time elapsed:  29108.9
# Run:  8100 of 9000 Time elapsed:  29146.4
# Run:  8400 of 9000 Time elapsed:  29179.1
# Run:  8700 of 9000 Time elapsed:  29208.0
# Generation 13  successful. Time elapsed 29213.6
# Run:  0 of 9000 Time elapsed:  29303.2
# Run:  300 of 9000 Time elapsed:  29388.4
# Run:  600 of 9000 Time elapsed:  29470.9
# Run:  900 of 9000 Time elapsed:  29553.6
# Run:  1200 of 9000 Time elapsed:  29634.8
# Run:  1500 of 9000 Time elapsed:  29713.7
# Run:  1800 of 9000 Time elapsed:  29790.4
# Run:  2100 of 9000 Time elapsed:  29865.1
# Run:  2400 of 9000 Time elapsed:  29937.3
# Run:  2700 of 9000 Time elapsed:  30007.5
# Run:  3000 of 9000 Time elapsed:  30074.7
# Run:  3300 of 9000 Time elapsed:  30138.6
# Run:  3600 of 9000 Time elapsed:  30198.7
# Run:  3900 of 9000 Time elapsed:  30256.7
# Run:  4200 of 9000 Time elapsed:  30312.8
# Run:  4500 of 9000 Time elapsed:  30367.1
# Run:  4800 of 9000 Time elapsed:  30420.2
# Run:  5100 of 9000 Time elapsed:  30471.1
# Run:  5400 of 9000 Time elapsed:  30518.9
# Run:  5700 of 9000 Time elapsed:  30564.5
# Run:  6000 of 9000 Time elapsed:  30608.0
# Run:  6300 of 9000 Time elapsed:  30649.1
# Run:  6600 of 9000 Time elapsed:  30687.7
# Run:  6900 of 9000 Time elapsed:  30723.7
# Run:  7200 of 9000 Time elapsed:  30757.2
# Run:  7500 of 9000 Time elapsed:  30788.2
# Run:  7800 of 9000 Time elapsed:  30816.9
# Run:  8100 of 9000 Time elapsed:  30843.3
# Run:  8400 of 9000 Time elapsed:  30867.8
# Run:  8700 of 9000 Time elapsed:  30890.4
# Generation 14  successful. Time elapsed 30896.1
# Run:  0 of 9000 Time elapsed:  30995.9
# Run:  300 of 9000 Time elapsed:  31099.8
# Run:  600 of 9000 Time elapsed:  31202.7
# Run:  900 of 9000 Time elapsed:  31305.3
# Run:  1200 of 9000 Time elapsed:  31406.3
# Run:  1500 of 9000 Time elapsed:  31510.0
# Run:  1800 of 9000 Time elapsed:  31614.3
# Run:  2100 of 9000 Time elapsed:  31717.0
# Run:  2400 of 9000 Time elapsed:  31817.7
# Run:  2700 of 9000 Time elapsed:  31915.6
# Run:  3000 of 9000 Time elapsed:  32012.3
# Run:  3300 of 9000 Time elapsed:  32104.8
# Run:  3600 of 9000 Time elapsed:  32195.8
# Run:  3900 of 9000 Time elapsed:  32292.9
# Run:  4200 of 9000 Time elapsed:  32385.7
# Run:  4500 of 9000 Time elapsed:  32474.7
# Run:  4800 of 9000 Time elapsed:  32559.6
# Run:  5100 of 9000 Time elapsed:  32643.1
# Run:  5400 of 9000 Time elapsed:  32722.7
# Run:  5700 of 9000 Time elapsed:  32797.5
# Run:  6000 of 9000 Time elapsed:  32868.3
# Run:  6300 of 9000 Time elapsed:  32934.9
# Run:  6600 of 9000 Time elapsed:  32997.2
# Run:  6900 of 9000 Time elapsed:  33054.6
# Run:  7200 of 9000 Time elapsed:  33107.4
# Run:  7500 of 9000 Time elapsed:  33156.5
# Run:  7800 of 9000 Time elapsed:  33199.9
# Run:  8100 of 9000 Time elapsed:  33238.2
# Run:  8400 of 9000 Time elapsed:  33272.5
# Run:  8700 of 9000 Time elapsed:  33302.0
# Generation 15  successful. Time elapsed 33307.4
# Run:  0 of 9000 Time elapsed:  33409.2
# Run:  300 of 9000 Time elapsed:  33512.4
# Run:  600 of 9000 Time elapsed:  33618.2
# Run:  900 of 9000 Time elapsed:  33724.2
# Run:  1200 of 9000 Time elapsed:  33826.7
# Run:  1500 of 9000 Time elapsed:  33935.4
# Run:  1800 of 9000 Time elapsed:  34042.6
# Run:  2100 of 9000 Time elapsed:  34152.6
# Run:  2400 of 9000 Time elapsed:  34257.6
# Run:  2700 of 9000 Time elapsed:  34357.9
# Run:  3000 of 9000 Time elapsed:  34454.8
# Run:  3300 of 9000 Time elapsed:  34548.0
# Run:  3600 of 9000 Time elapsed:  34638.1
# Run:  3900 of 9000 Time elapsed:  34724.0
# Run:  4200 of 9000 Time elapsed:  34805.4
# Run:  4500 of 9000 Time elapsed:  34883.0
# Run:  4800 of 9000 Time elapsed:  34957.0
# Run:  5100 of 9000 Time elapsed:  35028.8
# Run:  5400 of 9000 Time elapsed:  35098.4
# Run:  5700 of 9000 Time elapsed:  35163.7
# Run:  6000 of 9000 Time elapsed:  35225.5
# Run:  6300 of 9000 Time elapsed:  35283.5
# Run:  6600 of 9000 Time elapsed:  35337.6
# Run:  6900 of 9000 Time elapsed:  35387.9
# Run:  7200 of 9000 Time elapsed:  35434.4
# Run:  7500 of 9000 Time elapsed:  35477.3
# Run:  7800 of 9000 Time elapsed:  35516.1
# Run:  8100 of 9000 Time elapsed:  35551.6
# Run:  8400 of 9000 Time elapsed:  35583.4
# Run:  8700 of 9000 Time elapsed:  35610.3
# Generation 16  successful. Time elapsed 35615.7
# Run:  0 of 9000 Time elapsed:  35717.6
# Run:  300 of 9000 Time elapsed:  35817.4
# Run:  600 of 9000 Time elapsed:  35914.7
# Run:  900 of 9000 Time elapsed:  36009.2
# Run:  1200 of 9000 Time elapsed:  36101.0
# Run:  1500 of 9000 Time elapsed:  36191.3
# Run:  1800 of 9000 Time elapsed:  36281.6
# Run:  2100 of 9000 Time elapsed:  36368.9
# Run:  2400 of 9000 Time elapsed:  36453.7
# Run:  2700 of 9000 Time elapsed:  36535.6
# Run:  3000 of 9000 Time elapsed:  36615.0
# Run:  3300 of 9000 Time elapsed:  36690.9
# Run:  3600 of 9000 Time elapsed:  36761.1
# Run:  3900 of 9000 Time elapsed:  36828.0
# Run:  4200 of 9000 Time elapsed:  36892.3
# Run:  4500 of 9000 Time elapsed:  36954.0
# Run:  4800 of 9000 Time elapsed:  37012.8
# Run:  5100 of 9000 Time elapsed:  37070.2
# Run:  5400 of 9000 Time elapsed:  37127.1
# Run:  5700 of 9000 Time elapsed:  37181.3
# Run:  6000 of 9000 Time elapsed:  37232.0
# Run:  6300 of 9000 Time elapsed:  37280.2
# Run:  6600 of 9000 Time elapsed:  37326.1
# Run:  6900 of 9000 Time elapsed:  37368.9
# Run:  7200 of 9000 Time elapsed:  37407.6
# Run:  7500 of 9000 Time elapsed:  37443.2
# Run:  7800 of 9000 Time elapsed:  37475.3
# Run:  8100 of 9000 Time elapsed:  37504.4
# Run:  8400 of 9000 Time elapsed:  37530.7
# Run:  8700 of 9000 Time elapsed:  37554.2
# Generation 17  successful. Time elapsed 37559.6
# Run:  0 of 9000 Time elapsed:  37651.1
# Run:  300 of 9000 Time elapsed:  37742.5
# Run:  600 of 9000 Time elapsed:  37834.5
# Run:  900 of 9000 Time elapsed:  37924.8
# Run:  1200 of 9000 Time elapsed:  38013.7
# Run:  1500 of 9000 Time elapsed:  38100.9
# Run:  1800 of 9000 Time elapsed:  38186.8
# Run:  2100 of 9000 Time elapsed:  38273.8
# Run:  2400 of 9000 Time elapsed:  38360.0
# Run:  2700 of 9000 Time elapsed:  38445.9
# Run:  3000 of 9000 Time elapsed:  38534.4
# Run:  3300 of 9000 Time elapsed:  38620.7
# Run:  3600 of 9000 Time elapsed:  38708.2
# Run:  3900 of 9000 Time elapsed:  38792.2
# Run:  4200 of 9000 Time elapsed:  38882.1
# Run:  4500 of 9000 Time elapsed:  38981.1
# Run:  4800 of 9000 Time elapsed:  39075.0
# Run:  5100 of 9000 Time elapsed:  39161.6
# Run:  5400 of 9000 Time elapsed:  39242.8
# Run:  5700 of 9000 Time elapsed:  39319.2
# Run:  6000 of 9000 Time elapsed:  39391.0
# Run:  6300 of 9000 Time elapsed:  39457.2
# Run:  6600 of 9000 Time elapsed:  39518.9
# Run:  6900 of 9000 Time elapsed:  39576.2
# Run:  7200 of 9000 Time elapsed:  39631.4
# Run:  7500 of 9000 Time elapsed:  39681.8
# Run:  7800 of 9000 Time elapsed:  39727.0
# Run:  8100 of 9000 Time elapsed:  39767.9
# Run:  8400 of 9000 Time elapsed:  39804.2
# Run:  8700 of 9000 Time elapsed:  39835.7
# Generation 18  successful. Time elapsed 39841.3
# Run:  0 of 9000 Time elapsed:  39957.3
# Run:  300 of 9000 Time elapsed:  40073.6
# Run:  600 of 9000 Time elapsed:  40186.7
# Run:  900 of 9000 Time elapsed:  40292.6
# Run:  1200 of 9000 Time elapsed:  40397.4
# Run:  1500 of 9000 Time elapsed:  40514.4
# Run:  1800 of 9000 Time elapsed:  40624.9
# Run:  2100 of 9000 Time elapsed:  40731.0
# Run:  2400 of 9000 Time elapsed:  40838.5
# Run:  2700 of 9000 Time elapsed:  40939.5
# Run:  3000 of 9000 Time elapsed:  41034.7
# Run:  3300 of 9000 Time elapsed:  41125.9
# Run:  3600 of 9000 Time elapsed:  41213.3
# Run:  3900 of 9000 Time elapsed:  41296.9
# Run:  4200 of 9000 Time elapsed:  41377.2
# Run:  4500 of 9000 Time elapsed:  41454.1
# Run:  4800 of 9000 Time elapsed:  41527.1
# Run:  5100 of 9000 Time elapsed:  41598.0
# Run:  5400 of 9000 Time elapsed:  41666.5
# Run:  5700 of 9000 Time elapsed:  41731.4
# Run:  6000 of 9000 Time elapsed:  41793.2
# Run:  6300 of 9000 Time elapsed:  41851.3
# Run:  6600 of 9000 Time elapsed:  41905.7
# Run:  6900 of 9000 Time elapsed:  41956.6
# Run:  7200 of 9000 Time elapsed:  42002.6
# Run:  7500 of 9000 Time elapsed:  42044.3
# Run:  7800 of 9000 Time elapsed:  42082.1
# Run:  8100 of 9000 Time elapsed:  42116.3
# Run:  8400 of 9000 Time elapsed:  42146.6
# Run:  8700 of 9000 Time elapsed:  42173.0
# Generation 19  successful. Time elapsed 42178.3
# Run:  0 of 9000 Time elapsed:  42289.4
# Run:  300 of 9000 Time elapsed:  42399.4
# Run:  600 of 9000 Time elapsed:  42506.6
# Run:  900 of 9000 Time elapsed:  42611.4
# Run:  1200 of 9000 Time elapsed:  42713.2
# Run:  1500 of 9000 Time elapsed:  42811.6
# Run:  1800 of 9000 Time elapsed:  42903.2
# Run:  2100 of 9000 Time elapsed:  42994.0
# Run:  2400 of 9000 Time elapsed:  43082.9
# Run:  2700 of 9000 Time elapsed:  43168.7
# Run:  3000 of 9000 Time elapsed:  43251.4
# Run:  3300 of 9000 Time elapsed:  43331.4
# Run:  3600 of 9000 Time elapsed:  43408.0
# Run:  3900 of 9000 Time elapsed:  43482.3
# Run:  4200 of 9000 Time elapsed:  43552.2
# Run:  4500 of 9000 Time elapsed:  43616.8
# Run:  4800 of 9000 Time elapsed:  43678.6
# Run:  5100 of 9000 Time elapsed:  43737.2
# Run:  5400 of 9000 Time elapsed:  43792.5
# Run:  5700 of 9000 Time elapsed:  43844.8
# Run:  6000 of 9000 Time elapsed:  43894.0
# Run:  6300 of 9000 Time elapsed:  43940.0
# Run:  6600 of 9000 Time elapsed:  43983.2
# Run:  6900 of 9000 Time elapsed:  44024.0
# Run:  7200 of 9000 Time elapsed:  44062.9
# Run:  7500 of 9000 Time elapsed:  44100.4
# Run:  7800 of 9000 Time elapsed:  44134.9
# Run:  8100 of 9000 Time elapsed:  44166.4
# Run:  8400 of 9000 Time elapsed:  44194.7
# Run:  8700 of 9000 Time elapsed:  44219.9
