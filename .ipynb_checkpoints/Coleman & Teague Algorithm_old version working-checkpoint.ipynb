# %% [markdown]
# # Manipulation algorithm
# This notebook will apply Algorithm 1 to a given profile of voters and candidates. A notebook format is used to provide commentary and illustrate step-by-step the process in the algorithm.

# %%
#Key package imports
from itertools import permutations
import spatialGeneration
import itertools
import csv
import copy
import math
import matplotlib.pyplot as plt
import time

# %%
def setup():
    """setup()
    Takes the number of candidates, current voter rankings and coalition size.
    Creates a dictionary with the current votes for each candidate, and a list
    of potential elimination orders."""

    # list of ordered votes that we already know about
    """voter1 = {"A":1, "B": 2, "C": 3, "D": 4}
    voter2 = {"A":3, "B": 1, "C": 2, "D": 4}
    voter3 = {"A":1, "B": 2, "C": 3, "D": 4}
    voting_array = [voter1,voter2,voter3]"""
    
    voting_array = []
    #read csv for list of ordered votes that we already know about
    #with open("Exports/Export1678356411.497025.csv","r",newline='\n') as file:
    #    reader = csv.reader(file, delimiter=',')
    #    candidates = next(reader)
    #    #print(candidates)
    #    number_of_cands = len(candidates)
    #    for row in reader:
            #print(row)
    #        Vote = dict(zip(candidates,[int(i) for i in row]))
    #        voting_array.append(Vote)
            #print(voting_array)
    voting_array = copy.deepcopy(gen_Ranking)
    candidates = copy.deepcopy(gen_Candidates)
    #voting_array.pop(0) #necessary to delete headers
    #print(voting_array)
    candidates_and_votes = tally_votes(voting_array, candidates)

    # potential orders of elimination of candidates
    elimination_orders= []
    # Get permutations of n-1 candidates
    cand = list(candidates_and_votes.keys())
    perms_of_candidates = permutations(cand[0:len(candidates)-1])
    for i in perms_of_candidates:
        x = list(i)+[cand[-1]]
        elimination_orders.append(x)
    #print("orders: ",elimination_orders)
    #print(candidates_and_votes,voting_array)
    return candidates_and_votes, elimination_orders, voting_array, candidates

# %%
def tally_votes(v_array, candidates):
    # the candidates and the number of 1st choice votes they have
    candidates_and_votes = {candidates[i]:0 for i in range(0,len(candidates))}
    #print(candidates_and_votes)
    
    # add each voter's current 1st choice to the voting_array
    #print(voting_array)
    for voter in v_array:
        #print(voter)
        for key in voter:
            if voter[key]==1:
                candidates_and_votes[key]+=1
    return(candidates_and_votes)

# %%
def remove_orders(unsuccesful_start):
    elimination_orders_remove = []
    k = len(unsuccesful_start) 
    copy = elimination_orders.copy()
    for i in copy:
        if i[0:k] == unsuccesful_start:
            elimination_orders.remove(i)

# %%
def check_order(candidates_and_votes, order, col_size, voting_array, candidates):
    coalition_size = copy.deepcopy(col_size)
    voting_array_c = copy.deepcopy(voting_array)
    #print("HERE",candidates_and_votes)
    coalition_votes = []
    coalition_store = []
    dic__coalition_votes = []
    eliminated_candidates = []
    candidates_remaining = copy.deepcopy(candidates)
    for i in range(0,coalition_size):
        coalition_votes.append([])
    count = 1
    # copy of candidates and votes
    variable_votes = dict(candidates_and_votes)
    for i in order:
        eliminated_candidates.append(i)
        for j in order[order.index(i)+1:]:
            # compute votes required for j to beat i
            votes_req = int(variable_votes[i]) - int(variable_votes[j]) + 1
            # check that difference is positive
            if votes_req > 0:
                if len(coalition_votes) >= votes_req: # check if coalition size >= votes required to make j beat i
                    variable_votes[j] += votes_req
                    # decrease the amount of votes we can maniplulate this round
                    for c in range(0,votes_req):
                        coalition_votes[0].append(j)
                        coalition_store.append(coalition_votes[0])
                        coalition_votes.remove(coalition_votes[0])

                else:
                    # coalition was too small
                    remove_orders(eliminated_candidates)
                    #print("Elimination order is impossible", order)
                    return "fail","fail"
                    #return [], ord
        candidates_remaining.remove(i)
        if count <= len(order): # no point in doing the very last step of redistrbuting
            for en, voter in enumerate(voting_array_c):
                # Changes any first preference votes to the next available candidate in their preference order
                if voter[i] == 1:
                    voting_array_c[en] = {key: voter[key]-1 for key in voter}
        
                else:
                    # Eliminate candidate i from everyone elses list   
                    voting_array_c[en][i]=0                            
                    for key, value in voter.items():
                        """
                        print("i:",i," ",type(i),"\n",
                              "voter:",voter," ",type(voter),
                              "key:",key," ",type(key),"\n",
                              "value:",value, " ", type(key))"""
                        if int(value) > int(voter[i]):
                            voting_array_c[en][key] += -1
                count +=1
        #print(coalition_store)
        for b in coalition_store:
            if list(set(b).intersection(set(candidates_remaining))) == []:
                coalition_votes.insert(0,b)
                coalition_store.remove(b)
            # voters in coalitions next spot available to be filled
            
            
    coalition_votes += coalition_store
    #print("Successful Manipulation: ", ord)
    for v in coalition_votes:
        
        back_ord = order[::-1]
        #print("BACK ORD:",back_ord)
        dif = list(sorted(set(back_ord) - set(v), key=order.index))
        #print("V:",v)
        v += dif[::-1]
        #print("V+dif:",v)
        #print("NEW DICT:",{key: value+1 for value, key in enumerate(v)})
        dic__coalition_votes.append({key: value+1 for value, key in enumerate(v)})
        #print(order)
        #print({key: value+1 for value, key in enumerate(v)})
    return dic__coalition_votes, order

# %%
def check_manipulation(votes, k, candidates):
    all_votes = votes
    #print("CHECK MANIPULATION OF: ")
    # loop over number of eliminations (n-1 candidates)
    for i in range(0,k-1):
        #print(candidates)
        c_and_v = tally_votes(all_votes, candidates)
        #print("\n c_and_v: ",c_and_v)
        # there can't be ties by construction 
        # needs changing to elimate all candidates with votes = 0 / minimum, and change to while loop (while not just one candidate left with none-zero votes - what if tie?)
        if i == 0:
            elim_cand = min(c_and_v, key=c_and_v.get) #get candidate with least 1st choice votess
        else:
            elim_cand = min(x for x in c_and_v if  c_and_v[x] != 0)
        for en, vote_dict in enumerate(all_votes):
            #print("before", vote_dict)
            #print(elim_cand)
            # Changes any first preference votes to the next available candidate in their preference order
            if vote_dict[elim_cand] == 1:
                all_votes[en] = {key: vote_dict[key]-1 for key in vote_dict}
                all_votes[en].pop(elim_cand)
            else:
                # Eliminate candidate i from everyone elses list
                #all_votes[en][elim_cand] = 0
                for key, value in vote_dict.items():
                    if value > vote_dict[elim_cand]:
                        all_votes[en][key] += -1
                all_votes[en].pop(elim_cand)
           # print("after", all_votes[en])
        candidates.remove(elim_cand)
    #print("CANDIDATES",candidates)
    c_and_v = tally_votes(all_votes, candidates)
    #print("\n c_and_v: ",c_and_v)  
    #print(c_and_v,"\n")

    return (max(c_and_v, key=c_and_v.get))

# %%
#setup()

# %%
#coalition_array = []
#candidates_and_votes, elimination_orders, voting_array,candidates = setup()
#coalition_size = 2000

#for order in elimination_orders:
#    a,b = check_order(candidates_and_votes, order, coalition_size, voting_array,candidates)
#    #print("a: ",a)
#    #print("b: ",b)
#    #coalition_array.append([a,b])
#    if b != "fail":
#        y, yy, yyy,yyyy = setup()
#        check_votes = yyy + a
#       winner = check_manipulation(check_votes,len(yyyy),yyyy)
#        print(b, winner)

# %%
#gen_Ranking,gen_Candidates = spatialGeneration.returnRankings(5,100)

# %% [markdown]
# # Varying $\mathcal{K}$

# %%
gen_Ranking, gen_Candidates = spatialGeneration.returnRankings(5,100)

# %%
candidates_and_votes, elimination_orders, va, candidates = setup()
#coalition_size = 490
#MR = 0
def Cal_MR_K(col):
    MR = 0
    candidates_and_votes, elimination_orders, va, candidates = setup()
    for order in elimination_orders:
        a,b = check_order(candidates_and_votes, order, col, va, gen_Candidates)
        if a != "fail":
            MR += 1
    return MR/(math.factorial(len(gen_Candidates)-1))

# %%
print(math.factorial(len(gen_Candidates)-1))

store = []
for r in range(0,150):
    #candidates_and_votes, elimination_orders, va, candidates = setup()
    store.append(Cal_MR_K(r))
#print(elimination_orders)
plt.plot(range(0,150),store)
plt.ylabel("$MR$ rate")
plt.xlabel("$\mathcal{K}$ (coalition size)")
plt.title("Ratio of possible elimination orders in which $c^*$ wins")
plt.show()
# Out:
# 24

# %%
START = time.time()
stores = []
runs=20
for j in range(0,runs):
    print(j)
    gen_Ranking, gen_Candidates = spatialGeneration.returnRankings(9,100)
    print("Generation successful. Time elapsed",round(time.time()-START,1))
    candidates_and_votes, elimination_orders, va, candidates = setup()
    def Cal_MR_K(col):
        MR = 0
        candidates_and_votes, elimination_orders, va, candidates = setup()
        for order in elimination_orders:
            a,b = check_order(candidates_and_votes, order, col, va, gen_Candidates)
            if a != "fail":
                MR += 1
        return MR/(math.factorial(len(gen_Candidates)-1))

    store = []
    for r in range(0,150):
        #candidates_and_votes, elimination_orders, va, candidates = setup()
        if r%3==0:
            store.append(Cal_MR_K(r))
            print("Run: ",j,"of",runs, "k: ",r, "Time elapsed: ", round(time.time()-START,1))
        else:
            store.append(store[-1])
    
    
    stores.append(store)
    plt.plot(range(0,150),store)
    
plt.ylabel("$MR$ rate")
plt.xlabel("$\mathcal{K}$ (coalition size)")
plt.title("Ratio of possible elimination orders in which $c^*$ wins")
plt.show()
# Out:
# 0
# Generation successful. Time elapsed 0.1
# Run:  0 of 20 k:  0 Time elapsed:  106.8
# Run:  0 of 20 k:  3 Time elapsed:  139.9
# Run:  0 of 20 k:  6 Time elapsed:  174.3
# Run:  0 of 20 k:  9 Time elapsed:  208.3
# Run:  0 of 20 k:  12 Time elapsed:  242.3
# Run:  0 of 20 k:  15 Time elapsed:  276.4
# Run:  0 of 20 k:  18 Time elapsed:  311.8
# Run:  0 of 20 k:  21 Time elapsed:  347.3
# Run:  0 of 20 k:  24 Time elapsed:  384.1
# Run:  0 of 20 k:  27 Time elapsed:  420.8
# Run:  0 of 20 k:  30 Time elapsed:  457.9
# Run:  0 of 20 k:  33 Time elapsed:  495.2
# Run:  0 of 20 k:  36 Time elapsed:  535.2
# Run:  0 of 20 k:  39 Time elapsed:  575.4
# Run:  0 of 20 k:  42 Time elapsed:  618.4
# Run:  0 of 20 k:  45 Time elapsed:  663.5
# Run:  0 of 20 k:  48 Time elapsed:  709.4
# Run:  0 of 20 k:  51 Time elapsed:  755.7
# Run:  0 of 20 k:  54 Time elapsed:  803.0
# Run:  0 of 20 k:  57 Time elapsed:  849.8
# Run:  0 of 20 k:  60 Time elapsed:  895.3
# Run:  0 of 20 k:  63 Time elapsed:  941.3
# Run:  0 of 20 k:  66 Time elapsed:  987.7
# Run:  0 of 20 k:  69 Time elapsed:  1034.8
# Run:  0 of 20 k:  72 Time elapsed:  1082.2
# Run:  0 of 20 k:  75 Time elapsed:  1130.1
# Run:  0 of 20 k:  78 Time elapsed:  1178.9
# Run:  0 of 20 k:  81 Time elapsed:  1228.8
# Run:  0 of 20 k:  84 Time elapsed:  1280.7
# Run:  0 of 20 k:  87 Time elapsed:  1333.7
# Run:  0 of 20 k:  90 Time elapsed:  1387.3
# Run:  0 of 20 k:  93 Time elapsed:  1444.4
# Run:  0 of 20 k:  96 Time elapsed:  1502.6
# Run:  0 of 20 k:  99 Time elapsed:  1563.4
# Run:  0 of 20 k:  102 Time elapsed:  1623.2
# Run:  0 of 20 k:  105 Time elapsed:  1683.8
# Run:  0 of 20 k:  108 Time elapsed:  1745.7
# Run:  0 of 20 k:  111 Time elapsed:  1809.0
# Run:  0 of 20 k:  114 Time elapsed:  1871.2
# Run:  0 of 20 k:  117 Time elapsed:  1934.5
# Run:  0 of 20 k:  120 Time elapsed:  1998.1
# Run:  0 of 20 k:  123 Time elapsed:  2065.3
# Run:  0 of 20 k:  126 Time elapsed:  2134.2
# Run:  0 of 20 k:  129 Time elapsed:  2203.7
# Run:  0 of 20 k:  132 Time elapsed:  2273.2
# Run:  0 of 20 k:  135 Time elapsed:  2342.9
# Run:  0 of 20 k:  138 Time elapsed:  2412.6
# Run:  0 of 20 k:  141 Time elapsed:  2483.0
# Run:  0 of 20 k:  144 Time elapsed:  2551.9
# Run:  0 of 20 k:  147 Time elapsed:  2621.1
# 1
# Generation successful. Time elapsed 2621.2
# Run:  1 of 20 k:  0 Time elapsed:  2727.3
# Run:  1 of 20 k:  3 Time elapsed:  2760.4
# Run:  1 of 20 k:  6 Time elapsed:  2793.5
# Run:  1 of 20 k:  9 Time elapsed:  2826.6
# Run:  1 of 20 k:  12 Time elapsed:  2862.0
# Run:  1 of 20 k:  15 Time elapsed:  2897.5
# Run:  1 of 20 k:  18 Time elapsed:  2933.2
# Run:  1 of 20 k:  21 Time elapsed:  2969.6
# Run:  1 of 20 k:  24 Time elapsed:  3010.5
# Run:  1 of 20 k:  27 Time elapsed:  3052.0
# Run:  1 of 20 k:  30 Time elapsed:  3093.9
# Run:  1 of 20 k:  33 Time elapsed:  3136.6
# Run:  1 of 20 k:  36 Time elapsed:  3179.9
# Run:  1 of 20 k:  39 Time elapsed:  3225.2
# Run:  1 of 20 k:  42 Time elapsed:  3270.9
# Run:  1 of 20 k:  45 Time elapsed:  3317.6
# Run:  1 of 20 k:  48 Time elapsed:  3365.1
# Run:  1 of 20 k:  51 Time elapsed:  3413.6
# Run:  1 of 20 k:  54 Time elapsed:  3463.0
# Run:  1 of 20 k:  57 Time elapsed:  3513.0
# Run:  1 of 20 k:  60 Time elapsed:  3563.2
# Run:  1 of 20 k:  63 Time elapsed:  3612.7
# Run:  1 of 20 k:  66 Time elapsed:  3662.4
# Run:  1 of 20 k:  69 Time elapsed:  3713.3
# Run:  1 of 20 k:  72 Time elapsed:  3766.5
# Run:  1 of 20 k:  75 Time elapsed:  3819.8
# Run:  1 of 20 k:  78 Time elapsed:  3874.4
# Run:  1 of 20 k:  81 Time elapsed:  3930.5
# Run:  1 of 20 k:  84 Time elapsed:  3987.1
# Run:  1 of 20 k:  87 Time elapsed:  4043.9
# Run:  1 of 20 k:  90 Time elapsed:  4101.0
# Run:  1 of 20 k:  93 Time elapsed:  4158.4
# Run:  1 of 20 k:  96 Time elapsed:  4216.8
# Run:  1 of 20 k:  99 Time elapsed:  4277.3
# Run:  1 of 20 k:  102 Time elapsed:  4338.2
# Run:  1 of 20 k:  105 Time elapsed:  4399.6
# Run:  1 of 20 k:  108 Time elapsed:  4461.1
# Run:  1 of 20 k:  111 Time elapsed:  4521.0
# Run:  1 of 20 k:  114 Time elapsed:  4581.3
# Run:  1 of 20 k:  117 Time elapsed:  4641.4
# Run:  1 of 20 k:  120 Time elapsed:  4702.7
# Run:  1 of 20 k:  123 Time elapsed:  4763.6
# Run:  1 of 20 k:  126 Time elapsed:  4825.7
# Run:  1 of 20 k:  129 Time elapsed:  4889.8
# Run:  1 of 20 k:  132 Time elapsed:  4954.4
# Run:  1 of 20 k:  135 Time elapsed:  5019.0
# Run:  1 of 20 k:  138 Time elapsed:  5084.0
# Run:  1 of 20 k:  141 Time elapsed:  5149.8
# Run:  1 of 20 k:  144 Time elapsed:  5215.8
# Run:  1 of 20 k:  147 Time elapsed:  5279.2
# 2
# Generation successful. Time elapsed 5279.3
# Run:  2 of 20 k:  0 Time elapsed:  5382.9
# Run:  2 of 20 k:  3 Time elapsed:  5415.8
# Run:  2 of 20 k:  6 Time elapsed:  5448.7
# Run:  2 of 20 k:  9 Time elapsed:  5483.1
# Run:  2 of 20 k:  12 Time elapsed:  5518.6
# Run:  2 of 20 k:  15 Time elapsed:  5555.5
# Run:  2 of 20 k:  18 Time elapsed:  5592.4
# Run:  2 of 20 k:  21 Time elapsed:  5630.7
# Run:  2 of 20 k:  24 Time elapsed:  5668.9
# Run:  2 of 20 k:  27 Time elapsed:  5707.3
# Run:  2 of 20 k:  30 Time elapsed:  5745.9
# Run:  2 of 20 k:  33 Time elapsed:  5784.5
# Run:  2 of 20 k:  36 Time elapsed:  5823.1
# Run:  2 of 20 k:  39 Time elapsed:  5862.2
# Run:  2 of 20 k:  42 Time elapsed:  5901.8
# Run:  2 of 20 k:  45 Time elapsed:  5942.3
# Run:  2 of 20 k:  48 Time elapsed:  5983.2
# Run:  2 of 20 k:  51 Time elapsed:  6024.9
# Run:  2 of 20 k:  54 Time elapsed:  6067.1
# Run:  2 of 20 k:  57 Time elapsed:  6109.0
# Run:  2 of 20 k:  60 Time elapsed:  6150.8
# Run:  2 of 20 k:  63 Time elapsed:  6193.3
# Run:  2 of 20 k:  66 Time elapsed:  6237.5
# Run:  2 of 20 k:  69 Time elapsed:  6283.6
# Run:  2 of 20 k:  72 Time elapsed:  6330.6
# Run:  2 of 20 k:  75 Time elapsed:  6378.9
# Run:  2 of 20 k:  78 Time elapsed:  6428.0
# Run:  2 of 20 k:  81 Time elapsed:  6479.4
# Run:  2 of 20 k:  84 Time elapsed:  6531.9
# Run:  2 of 20 k:  87 Time elapsed:  6587.9
# Run:  2 of 20 k:  90 Time elapsed:  6651.5
# Run:  2 of 20 k:  93 Time elapsed:  6711.7
# Run:  2 of 20 k:  96 Time elapsed:  6778.4
# Run:  2 of 20 k:  99 Time elapsed:  6842.1
# Run:  2 of 20 k:  102 Time elapsed:  6906.3
# Run:  2 of 20 k:  105 Time elapsed:  6971.3
# Run:  2 of 20 k:  108 Time elapsed:  7036.4
# Run:  2 of 20 k:  111 Time elapsed:  7101.9
# Run:  2 of 20 k:  114 Time elapsed:  7166.7
# Run:  2 of 20 k:  117 Time elapsed:  7229.8
# Run:  2 of 20 k:  120 Time elapsed:  7293.2
# Run:  2 of 20 k:  123 Time elapsed:  7356.9
# Run:  2 of 20 k:  126 Time elapsed:  7422.6
# Run:  2 of 20 k:  129 Time elapsed:  7490.1
# Run:  2 of 20 k:  132 Time elapsed:  7557.8
# Run:  2 of 20 k:  135 Time elapsed:  7625.7
# Run:  2 of 20 k:  138 Time elapsed:  7694.2
# Run:  2 of 20 k:  141 Time elapsed:  7763.2
# Run:  2 of 20 k:  144 Time elapsed:  7832.3
# Run:  2 of 20 k:  147 Time elapsed:  7901.9
# 3
# Generation successful. Time elapsed 7902.0
# Run:  3 of 20 k:  0 Time elapsed:  8009.6
# Run:  3 of 20 k:  3 Time elapsed:  8044.7
# Run:  3 of 20 k:  6 Time elapsed:  8079.8
# Run:  3 of 20 k:  9 Time elapsed:  8116.4
# Run:  3 of 20 k:  12 Time elapsed:  8152.6
# Run:  3 of 20 k:  15 Time elapsed:  8189.0
# Run:  3 of 20 k:  18 Time elapsed:  8225.3
# Run:  3 of 20 k:  21 Time elapsed:  8261.6
# Run:  3 of 20 k:  24 Time elapsed:  8298.0
# Run:  3 of 20 k:  27 Time elapsed:  8335.7
# Run:  3 of 20 k:  30 Time elapsed:  8374.8
# Run:  3 of 20 k:  33 Time elapsed:  8415.0
# Run:  3 of 20 k:  36 Time elapsed:  8455.6
# Run:  3 of 20 k:  39 Time elapsed:  8496.6
# Run:  3 of 20 k:  42 Time elapsed:  8537.6
# Run:  3 of 20 k:  45 Time elapsed:  8578.9
# Run:  3 of 20 k:  48 Time elapsed:  8620.5
# Run:  3 of 20 k:  51 Time elapsed:  8662.8
# Run:  3 of 20 k:  54 Time elapsed:  8705.6
# Run:  3 of 20 k:  57 Time elapsed:  8750.5
# Run:  3 of 20 k:  60 Time elapsed:  8796.1
# Run:  3 of 20 k:  63 Time elapsed:  8843.2
# Run:  3 of 20 k:  66 Time elapsed:  8892.0
# Run:  3 of 20 k:  69 Time elapsed:  8941.5
# Run:  3 of 20 k:  72 Time elapsed:  8991.2
# Run:  3 of 20 k:  75 Time elapsed:  9040.9
# Run:  3 of 20 k:  78 Time elapsed:  9091.3
# Run:  3 of 20 k:  81 Time elapsed:  9142.5
# Run:  3 of 20 k:  84 Time elapsed:  9194.4
# Run:  3 of 20 k:  87 Time elapsed:  9249.8
# Run:  3 of 20 k:  90 Time elapsed:  9306.4
# Run:  3 of 20 k:  93 Time elapsed:  9363.6
# Run:  3 of 20 k:  96 Time elapsed:  9421.4
# Run:  3 of 20 k:  99 Time elapsed:  9481.4
# Run:  3 of 20 k:  102 Time elapsed:  9541.5
# Run:  3 of 20 k:  105 Time elapsed:  9604.4
# Run:  3 of 20 k:  108 Time elapsed:  9668.3
# Run:  3 of 20 k:  111 Time elapsed:  9732.6
# Run:  3 of 20 k:  114 Time elapsed:  9797.0
# Run:  3 of 20 k:  117 Time elapsed:  9859.4
# Run:  3 of 20 k:  120 Time elapsed:  9921.9
# Run:  3 of 20 k:  123 Time elapsed:  9984.8
# Run:  3 of 20 k:  126 Time elapsed:  10049.0
# Run:  3 of 20 k:  129 Time elapsed:  10115.5
# Run:  3 of 20 k:  132 Time elapsed:  10182.3
# Run:  3 of 20 k:  135 Time elapsed:  10250.0
# Run:  3 of 20 k:  138 Time elapsed:  10317.2
# Run:  3 of 20 k:  141 Time elapsed:  10384.9
# Run:  3 of 20 k:  144 Time elapsed:  10453.2
# Run:  3 of 20 k:  147 Time elapsed:  10521.6
# 4
# Generation successful. Time elapsed 10521.7
# Run:  4 of 20 k:  0 Time elapsed:  10628.1
# Run:  4 of 20 k:  3 Time elapsed:  10662.0
# Run:  4 of 20 k:  6 Time elapsed:  10696.0
# Run:  4 of 20 k:  9 Time elapsed:  10732.3
# Run:  4 of 20 k:  12 Time elapsed:  10769.9
# Run:  4 of 20 k:  15 Time elapsed:  10807.6
# Run:  4 of 20 k:  18 Time elapsed:  10846.3
# Run:  4 of 20 k:  21 Time elapsed:  10886.2
# Run:  4 of 20 k:  24 Time elapsed:  10927.6
# Run:  4 of 20 k:  27 Time elapsed:  10969.2
# Run:  4 of 20 k:  30 Time elapsed:  11010.9
# Run:  4 of 20 k:  33 Time elapsed:  11054.0
# Run:  4 of 20 k:  36 Time elapsed:  11097.4
# Run:  4 of 20 k:  39 Time elapsed:  11141.1
# Run:  4 of 20 k:  42 Time elapsed:  11185.3
# Run:  4 of 20 k:  45 Time elapsed:  11229.9
# Run:  4 of 20 k:  48 Time elapsed:  11274.8
# Run:  4 of 20 k:  51 Time elapsed:  11320.0
# Run:  4 of 20 k:  54 Time elapsed:  11365.2
# Run:  4 of 20 k:  57 Time elapsed:  11410.5
# Run:  4 of 20 k:  60 Time elapsed:  11456.0
# Run:  4 of 20 k:  63 Time elapsed:  11500.0
# Run:  4 of 20 k:  66 Time elapsed:  11544.1
# Run:  4 of 20 k:  69 Time elapsed:  11588.8
# Run:  4 of 20 k:  72 Time elapsed:  11634.0
# Run:  4 of 20 k:  75 Time elapsed:  11679.5
# Run:  4 of 20 k:  78 Time elapsed:  11724.9
# Run:  4 of 20 k:  81 Time elapsed:  11770.7
# Run:  4 of 20 k:  84 Time elapsed:  11819.2
# Run:  4 of 20 k:  87 Time elapsed:  11868.3
# Run:  4 of 20 k:  90 Time elapsed:  11918.3
# Run:  4 of 20 k:  93 Time elapsed:  11968.9
# Run:  4 of 20 k:  96 Time elapsed:  12019.5
# Run:  4 of 20 k:  99 Time elapsed:  12070.4
# Run:  4 of 20 k:  102 Time elapsed:  12121.9
# Run:  4 of 20 k:  105 Time elapsed:  12173.4
# Run:  4 of 20 k:  108 Time elapsed:  12226.1
# Run:  4 of 20 k:  111 Time elapsed:  12279.7
# Run:  4 of 20 k:  114 Time elapsed:  12334.1
# Run:  4 of 20 k:  117 Time elapsed:  12387.7
# Run:  4 of 20 k:  120 Time elapsed:  12440.3
# Run:  4 of 20 k:  123 Time elapsed:  12493.4
# Run:  4 of 20 k:  126 Time elapsed:  12546.6
# Run:  4 of 20 k:  129 Time elapsed:  12600.9
# Run:  4 of 20 k:  132 Time elapsed:  12656.7
# Run:  4 of 20 k:  135 Time elapsed:  12713.9
# Run:  4 of 20 k:  138 Time elapsed:  12771.3
# Run:  4 of 20 k:  141 Time elapsed:  12828.9
# Run:  4 of 20 k:  144 Time elapsed:  12887.5
# Run:  4 of 20 k:  147 Time elapsed:  12948.3
# 5
# Generation successful. Time elapsed 12948.3
# Run:  5 of 20 k:  0 Time elapsed:  13057.3
# Run:  5 of 20 k:  3 Time elapsed:  13091.8
# Run:  5 of 20 k:  6 Time elapsed:  13127.3
# Run:  5 of 20 k:  9 Time elapsed:  13162.9
# Run:  5 of 20 k:  12 Time elapsed:  13198.7
# Run:  5 of 20 k:  15 Time elapsed:  13236.0
# Run:  5 of 20 k:  18 Time elapsed:  13273.1
# Run:  5 of 20 k:  21 Time elapsed:  13312.9
# Run:  5 of 20 k:  24 Time elapsed:  13353.0
# Run:  5 of 20 k:  27 Time elapsed:  13394.2
# Run:  5 of 20 k:  30 Time elapsed:  13436.0
# Run:  5 of 20 k:  33 Time elapsed:  13478.0
# Run:  5 of 20 k:  36 Time elapsed:  13518.5
# Run:  5 of 20 k:  39 Time elapsed:  13559.3
# Run:  5 of 20 k:  42 Time elapsed:  13601.7
# Run:  5 of 20 k:  45 Time elapsed:  13644.6
# Run:  5 of 20 k:  48 Time elapsed:  13688.2
# Run:  5 of 20 k:  51 Time elapsed:  13732.5
# Run:  5 of 20 k:  54 Time elapsed:  13778.3
# Run:  5 of 20 k:  57 Time elapsed:  13825.6
# Run:  5 of 20 k:  60 Time elapsed:  13873.4
# Run:  5 of 20 k:  63 Time elapsed:  13922.0
# Run:  5 of 20 k:  66 Time elapsed:  13970.9
# Run:  5 of 20 k:  69 Time elapsed:  14020.6
# Run:  5 of 20 k:  72 Time elapsed:  14070.6
# Run:  5 of 20 k:  75 Time elapsed:  14121.4
# Run:  5 of 20 k:  78 Time elapsed:  14173.1
# Run:  5 of 20 k:  81 Time elapsed:  14225.2
# Run:  5 of 20 k:  84 Time elapsed:  14277.9
# Run:  5 of 20 k:  87 Time elapsed:  14331.9
# Run:  5 of 20 k:  90 Time elapsed:  14384.7
# Run:  5 of 20 k:  93 Time elapsed:  14437.4
# Run:  5 of 20 k:  96 Time elapsed:  14490.5
# Run:  5 of 20 k:  99 Time elapsed:  14544.7
# Run:  5 of 20 k:  102 Time elapsed:  14600.5
# Run:  5 of 20 k:  105 Time elapsed:  14656.6
# Run:  5 of 20 k:  108 Time elapsed:  14714.7
# Run:  5 of 20 k:  111 Time elapsed:  14773.0
# Run:  5 of 20 k:  114 Time elapsed:  14835.1
# Run:  5 of 20 k:  117 Time elapsed:  14897.2
# Run:  5 of 20 k:  120 Time elapsed:  14962.4
# Run:  5 of 20 k:  123 Time elapsed:  15028.0
# Run:  5 of 20 k:  126 Time elapsed:  15094.0
# Run:  5 of 20 k:  129 Time elapsed:  15160.2
# Run:  5 of 20 k:  132 Time elapsed:  15226.6
# Run:  5 of 20 k:  135 Time elapsed:  15293.8
# Run:  5 of 20 k:  138 Time elapsed:  15361.4
# Run:  5 of 20 k:  141 Time elapsed:  15429.4
# Run:  5 of 20 k:  144 Time elapsed:  15497.2
# Run:  5 of 20 k:  147 Time elapsed:  15562.5
# 6
# Generation successful. Time elapsed 15562.6
# Run:  6 of 20 k:  0 Time elapsed:  15665.8
# Run:  6 of 20 k:  3 Time elapsed:  15700.8
# Run:  6 of 20 k:  6 Time elapsed:  15735.9
# Run:  6 of 20 k:  9 Time elapsed:  15773.1
# Run:  6 of 20 k:  12 Time elapsed:  15811.2
# Run:  6 of 20 k:  15 Time elapsed:  15850.7
# Run:  6 of 20 k:  18 Time elapsed:  15890.2
# Run:  6 of 20 k:  21 Time elapsed:  15929.6
# Run:  6 of 20 k:  24 Time elapsed:  15969.2
# Run:  6 of 20 k:  27 Time elapsed:  16008.8
# Run:  6 of 20 k:  30 Time elapsed:  16049.9
# Run:  6 of 20 k:  33 Time elapsed:  16091.3
# Run:  6 of 20 k:  36 Time elapsed:  16132.8
# Run:  6 of 20 k:  39 Time elapsed:  16174.5
# Run:  6 of 20 k:  42 Time elapsed:  16216.2
# Run:  6 of 20 k:  45 Time elapsed:  16258.1
# Run:  6 of 20 k:  48 Time elapsed:  16300.2
# Run:  6 of 20 k:  51 Time elapsed:  16342.7
# Run:  6 of 20 k:  54 Time elapsed:  16385.6
# Run:  6 of 20 k:  57 Time elapsed:  16427.2
# Run:  6 of 20 k:  60 Time elapsed:  16468.8
# Run:  6 of 20 k:  63 Time elapsed:  16512.6
# Run:  6 of 20 k:  66 Time elapsed:  16557.1
# Run:  6 of 20 k:  69 Time elapsed:  16601.9
# Run:  6 of 20 k:  72 Time elapsed:  16647.9
# Run:  6 of 20 k:  75 Time elapsed:  16694.4
# Run:  6 of 20 k:  78 Time elapsed:  16742.6
# Run:  6 of 20 k:  81 Time elapsed:  16790.8
# Run:  6 of 20 k:  84 Time elapsed:  16840.5
# Run:  6 of 20 k:  87 Time elapsed:  16890.9
# Run:  6 of 20 k:  90 Time elapsed:  16941.8
# Run:  6 of 20 k:  93 Time elapsed:  16993.7
# Run:  6 of 20 k:  96 Time elapsed:  17046.3
# Run:  6 of 20 k:  99 Time elapsed:  17098.1
# Run:  6 of 20 k:  102 Time elapsed:  17149.3
# Run:  6 of 20 k:  105 Time elapsed:  17200.7
# Run:  6 of 20 k:  108 Time elapsed:  17252.8
# Run:  6 of 20 k:  111 Time elapsed:  17305.6
# Run:  6 of 20 k:  114 Time elapsed:  17359.4
# Run:  6 of 20 k:  117 Time elapsed:  17416.8
# Run:  6 of 20 k:  120 Time elapsed:  17475.0
# Run:  6 of 20 k:  123 Time elapsed:  17533.9
# Run:  6 of 20 k:  126 Time elapsed:  17593.2
# Run:  6 of 20 k:  129 Time elapsed:  17653.4
# Run:  6 of 20 k:  132 Time elapsed:  17713.8
# Run:  6 of 20 k:  135 Time elapsed:  17775.3
# Run:  6 of 20 k:  138 Time elapsed:  17839.6
# Run:  6 of 20 k:  141 Time elapsed:  17904.6
# Run:  6 of 20 k:  144 Time elapsed:  17968.6
# Run:  6 of 20 k:  147 Time elapsed:  18031.6
# 7
# Generation successful. Time elapsed 18031.6
# Run:  7 of 20 k:  0 Time elapsed:  18134.4
# Run:  7 of 20 k:  3 Time elapsed:  18168.3
# Run:  7 of 20 k:  6 Time elapsed:  18202.1
# Run:  7 of 20 k:  9 Time elapsed:  18237.2
# Run:  7 of 20 k:  12 Time elapsed:  18272.3
# Run:  7 of 20 k:  15 Time elapsed:  18307.6
# Run:  7 of 20 k:  18 Time elapsed:  18342.8
# Run:  7 of 20 k:  21 Time elapsed:  18378.1
# Run:  7 of 20 k:  24 Time elapsed:  18414.6
# Run:  7 of 20 k:  27 Time elapsed:  18452.5
# Run:  7 of 20 k:  30 Time elapsed:  18491.4
# Run:  7 of 20 k:  33 Time elapsed:  18530.5
# Run:  7 of 20 k:  36 Time elapsed:  18569.9
# Run:  7 of 20 k:  39 Time elapsed:  18611.1
# Run:  7 of 20 k:  42 Time elapsed:  18652.9
# Run:  7 of 20 k:  45 Time elapsed:  18695.6
# Run:  7 of 20 k:  48 Time elapsed:  18739.2
# Run:  7 of 20 k:  51 Time elapsed:  18783.6
# Run:  7 of 20 k:  54 Time elapsed:  18831.2
# Run:  7 of 20 k:  57 Time elapsed:  18879.7
# Run:  7 of 20 k:  60 Time elapsed:  18930.6
# Run:  7 of 20 k:  63 Time elapsed:  18983.9
# Run:  7 of 20 k:  66 Time elapsed:  19038.6
# Run:  7 of 20 k:  69 Time elapsed:  19092.7
# Run:  7 of 20 k:  72 Time elapsed:  19147.4
# Run:  7 of 20 k:  75 Time elapsed:  19203.1
# Run:  7 of 20 k:  78 Time elapsed:  19259.5
# Run:  7 of 20 k:  81 Time elapsed:  19315.9
# Run:  7 of 20 k:  84 Time elapsed:  19372.8
# Run:  7 of 20 k:  87 Time elapsed:  19430.0
# Run:  7 of 20 k:  90 Time elapsed:  19487.7
# Run:  7 of 20 k:  93 Time elapsed:  19545.9
# Run:  7 of 20 k:  96 Time elapsed:  19604.5
# Run:  7 of 20 k:  99 Time elapsed:  19662.9
# Run:  7 of 20 k:  102 Time elapsed:  19721.6
# Run:  7 of 20 k:  105 Time elapsed:  19780.7
# Run:  7 of 20 k:  108 Time elapsed:  19840.1
# Run:  7 of 20 k:  111 Time elapsed:  19900.7
# Run:  7 of 20 k:  114 Time elapsed:  19961.3
# Run:  7 of 20 k:  117 Time elapsed:  20022.0
# Run:  7 of 20 k:  120 Time elapsed:  20083.2
# Run:  7 of 20 k:  123 Time elapsed:  20147.2
# Run:  7 of 20 k:  126 Time elapsed:  20211.3
# Run:  7 of 20 k:  129 Time elapsed:  20276.0
# Run:  7 of 20 k:  132 Time elapsed:  20340.7
# Run:  7 of 20 k:  135 Time elapsed:  20405.9
# Run:  7 of 20 k:  138 Time elapsed:  20471.5
# Run:  7 of 20 k:  141 Time elapsed:  20537.3
# Run:  7 of 20 k:  144 Time elapsed:  20603.5
# Run:  7 of 20 k:  147 Time elapsed:  20669.9
# 8
# Generation successful. Time elapsed 20670.0
# Run:  8 of 20 k:  0 Time elapsed:  20773.5
# Run:  8 of 20 k:  3 Time elapsed:  20808.3
# Run:  8 of 20 k:  6 Time elapsed:  20843.9
# Run:  8 of 20 k:  9 Time elapsed:  20879.8
# Run:  8 of 20 k:  12 Time elapsed:  20915.5
# Run:  8 of 20 k:  15 Time elapsed:  20951.4
# Run:  8 of 20 k:  18 Time elapsed:  20988.5
# Run:  8 of 20 k:  21 Time elapsed:  21025.9
# Run:  8 of 20 k:  24 Time elapsed:  21063.3
# Run:  8 of 20 k:  27 Time elapsed:  21103.1
# Run:  8 of 20 k:  30 Time elapsed:  21143.5
# Run:  8 of 20 k:  33 Time elapsed:  21185.6
# Run:  8 of 20 k:  36 Time elapsed:  21227.8
# Run:  8 of 20 k:  39 Time elapsed:  21270.6
# Run:  8 of 20 k:  42 Time elapsed:  21314.3
# Run:  8 of 20 k:  45 Time elapsed:  21358.6
# Run:  8 of 20 k:  48 Time elapsed:  21402.6
# Run:  8 of 20 k:  51 Time elapsed:  21446.0
# Run:  8 of 20 k:  54 Time elapsed:  21491.0
# Run:  8 of 20 k:  57 Time elapsed:  21536.9
# Run:  8 of 20 k:  60 Time elapsed:  21583.9
# Run:  8 of 20 k:  63 Time elapsed:  21632.4
# Run:  8 of 20 k:  66 Time elapsed:  21681.3
# Run:  8 of 20 k:  69 Time elapsed:  21731.3
# Run:  8 of 20 k:  72 Time elapsed:  21782.1
# Run:  8 of 20 k:  75 Time elapsed:  21835.5
# Run:  8 of 20 k:  78 Time elapsed:  21890.4
# Run:  8 of 20 k:  81 Time elapsed:  21947.1
# Run:  8 of 20 k:  84 Time elapsed:  22004.5
# Run:  8 of 20 k:  87 Time elapsed:  22063.3
# Run:  8 of 20 k:  90 Time elapsed:  22123.6
# Run:  8 of 20 k:  93 Time elapsed:  22184.5
# Run:  8 of 20 k:  96 Time elapsed:  22245.6
# Run:  8 of 20 k:  99 Time elapsed:  22307.1
# Run:  8 of 20 k:  102 Time elapsed:  22368.9
# Run:  8 of 20 k:  105 Time elapsed:  22429.1
# Run:  8 of 20 k:  108 Time elapsed:  22488.7
# Run:  8 of 20 k:  111 Time elapsed:  22548.9
# Run:  8 of 20 k:  114 Time elapsed:  22609.3
# Run:  8 of 20 k:  117 Time elapsed:  22672.0
# Run:  8 of 20 k:  120 Time elapsed:  22735.6
# Run:  8 of 20 k:  123 Time elapsed:  22799.8
# Run:  8 of 20 k:  126 Time elapsed:  22864.1
# Run:  8 of 20 k:  129 Time elapsed:  22928.8
# Run:  8 of 20 k:  132 Time elapsed:  22993.7
# Run:  8 of 20 k:  135 Time elapsed:  23059.5
# Run:  8 of 20 k:  138 Time elapsed:  23125.6
# Run:  8 of 20 k:  141 Time elapsed:  23192.2
# Run:  8 of 20 k:  144 Time elapsed:  23257.3
# Run:  8 of 20 k:  147 Time elapsed:  23321.5
# 9
# Generation successful. Time elapsed 23321.6
# Run:  9 of 20 k:  0 Time elapsed:  23424.8
# Run:  9 of 20 k:  3 Time elapsed:  23458.7
# Run:  9 of 20 k:  6 Time elapsed:  23493.7
# Run:  9 of 20 k:  9 Time elapsed:  23530.4
# Run:  9 of 20 k:  12 Time elapsed:  23568.5
# Run:  9 of 20 k:  15 Time elapsed:  23606.7
# Run:  9 of 20 k:  18 Time elapsed:  23646.3
# Run:  9 of 20 k:  21 Time elapsed:  23686.0
# Run:  9 of 20 k:  24 Time elapsed:  23725.9
# Run:  9 of 20 k:  27 Time elapsed:  23766.3
# Run:  9 of 20 k:  30 Time elapsed:  23809.4
# Run:  9 of 20 k:  33 Time elapsed:  23853.2
# Run:  9 of 20 k:  36 Time elapsed:  23898.0
# Run:  9 of 20 k:  39 Time elapsed:  23942.8
# Run:  9 of 20 k:  42 Time elapsed:  23988.0
# Run:  9 of 20 k:  45 Time elapsed:  24033.8
# Run:  9 of 20 k:  48 Time elapsed:  24079.4
# Run:  9 of 20 k:  51 Time elapsed:  24124.5
# Run:  9 of 20 k:  54 Time elapsed:  24169.8
# Run:  9 of 20 k:  57 Time elapsed:  24215.5
# Run:  9 of 20 k:  60 Time elapsed:  24261.5
# Run:  9 of 20 k:  63 Time elapsed:  24308.2
# Run:  9 of 20 k:  66 Time elapsed:  24355.6
# Run:  9 of 20 k:  69 Time elapsed:  24403.8
# Run:  9 of 20 k:  72 Time elapsed:  24453.8
# Run:  9 of 20 k:  75 Time elapsed:  24503.2
# Run:  9 of 20 k:  78 Time elapsed:  24553.3
# Run:  9 of 20 k:  81 Time elapsed:  24606.7
# Run:  9 of 20 k:  84 Time elapsed:  24661.1
# Run:  9 of 20 k:  87 Time elapsed:  24716.5
# Run:  9 of 20 k:  90 Time elapsed:  24773.6
# Run:  9 of 20 k:  93 Time elapsed:  24831.1
# Run:  9 of 20 k:  96 Time elapsed:  24891.2
# Run:  9 of 20 k:  99 Time elapsed:  24951.7
# Run:  9 of 20 k:  102 Time elapsed:  25012.7
# Run:  9 of 20 k:  105 Time elapsed:  25074.0
# Run:  9 of 20 k:  108 Time elapsed:  25135.7
# Run:  9 of 20 k:  111 Time elapsed:  25195.4
# Run:  9 of 20 k:  114 Time elapsed:  25255.1
# Run:  9 of 20 k:  117 Time elapsed:  25314.9
# Run:  9 of 20 k:  120 Time elapsed:  25375.2
# Run:  9 of 20 k:  123 Time elapsed:  25435.6
# Run:  9 of 20 k:  126 Time elapsed:  25496.3
# Run:  9 of 20 k:  129 Time elapsed:  25557.2
# Run:  9 of 20 k:  132 Time elapsed:  25618.5
# Run:  9 of 20 k:  135 Time elapsed:  25680.1
# Run:  9 of 20 k:  138 Time elapsed:  25744.9
# Run:  9 of 20 k:  141 Time elapsed:  25810.4
# Run:  9 of 20 k:  144 Time elapsed:  25876.4
# Run:  9 of 20 k:  147 Time elapsed:  25942.7
# 10
# Generation successful. Time elapsed 25942.8
# Run:  10 of 20 k:  0 Time elapsed:  26052.0
# Run:  10 of 20 k:  3 Time elapsed:  26088.7
# Run:  10 of 20 k:  6 Time elapsed:  26125.6
# Run:  10 of 20 k:  9 Time elapsed:  26162.4
# Run:  10 of 20 k:  12 Time elapsed:  26199.3
# Run:  10 of 20 k:  15 Time elapsed:  26237.5
# Run:  10 of 20 k:  18 Time elapsed:  26275.6
# Run:  10 of 20 k:  21 Time elapsed:  26312.9
# Run:  10 of 20 k:  24 Time elapsed:  26349.2
# Run:  10 of 20 k:  27 Time elapsed:  26385.8
# Run:  10 of 20 k:  30 Time elapsed:  26422.5
# Run:  10 of 20 k:  33 Time elapsed:  26459.2
# Run:  10 of 20 k:  36 Time elapsed:  26496.2
# Run:  10 of 20 k:  39 Time elapsed:  26534.2
# Run:  10 of 20 k:  42 Time elapsed:  26572.0
# Run:  10 of 20 k:  45 Time elapsed:  26611.2
# Run:  10 of 20 k:  48 Time elapsed:  26653.0
# Run:  10 of 20 k:  51 Time elapsed:  26695.4
# Run:  10 of 20 k:  54 Time elapsed:  26738.9
# Run:  10 of 20 k:  57 Time elapsed:  26784.4
# Run:  10 of 20 k:  60 Time elapsed:  26831.0
# Run:  10 of 20 k:  63 Time elapsed:  26878.6
# Run:  10 of 20 k:  66 Time elapsed:  26927.4
# Run:  10 of 20 k:  69 Time elapsed:  26977.1
# Run:  10 of 20 k:  72 Time elapsed:  27029.4
# Run:  10 of 20 k:  75 Time elapsed:  27082.5
# Run:  10 of 20 k:  78 Time elapsed:  27137.4
# Run:  10 of 20 k:  81 Time elapsed:  27194.8
# Run:  10 of 20 k:  84 Time elapsed:  27250.3
# Run:  10 of 20 k:  87 Time elapsed:  27307.7
# Run:  10 of 20 k:  90 Time elapsed:  27366.1
# Run:  10 of 20 k:  93 Time elapsed:  27425.2
# Run:  10 of 20 k:  96 Time elapsed:  27484.7
# Run:  10 of 20 k:  99 Time elapsed:  27544.6
# Run:  10 of 20 k:  102 Time elapsed:  27604.7
# Run:  10 of 20 k:  105 Time elapsed:  27665.4
# Run:  10 of 20 k:  108 Time elapsed:  27726.2
# Run:  10 of 20 k:  111 Time elapsed:  27787.4
# Run:  10 of 20 k:  114 Time elapsed:  27849.0
# Run:  10 of 20 k:  117 Time elapsed:  27910.8
# Run:  10 of 20 k:  120 Time elapsed:  27972.9
# Run:  10 of 20 k:  123 Time elapsed:  28035.4
# Run:  10 of 20 k:  126 Time elapsed:  28098.6
# Run:  10 of 20 k:  129 Time elapsed:  28161.9
# Run:  10 of 20 k:  132 Time elapsed:  28225.5
# Run:  10 of 20 k:  135 Time elapsed:  28290.1
# Run:  10 of 20 k:  138 Time elapsed:  28357.2
# Run:  10 of 20 k:  141 Time elapsed:  28425.0
# Run:  10 of 20 k:  144 Time elapsed:  28492.6
# Run:  10 of 20 k:  147 Time elapsed:  28560.5
# 11
# Generation successful. Time elapsed 28560.6
# Run:  11 of 20 k:  0 Time elapsed:  28668.9
# Run:  11 of 20 k:  3 Time elapsed:  28704.2
# Run:  11 of 20 k:  6 Time elapsed:  28739.5
# Run:  11 of 20 k:  9 Time elapsed:  28774.6
# Run:  11 of 20 k:  12 Time elapsed:  28810.0
# Run:  11 of 20 k:  15 Time elapsed:  28845.2
# Run:  11 of 20 k:  18 Time elapsed:  28880.5
# Run:  11 of 20 k:  21 Time elapsed:  28918.1
# Run:  11 of 20 k:  24 Time elapsed:  28973.5
# Run:  11 of 20 k:  27 Time elapsed:  29011.4
# Run:  11 of 20 k:  30 Time elapsed:  29067.1
# Run:  11 of 20 k:  33 Time elapsed:  29105.1
# Run:  11 of 20 k:  36 Time elapsed:  29143.3
# Run:  11 of 20 k:  39 Time elapsed:  29181.8
# Run:  11 of 20 k:  42 Time elapsed:  29220.5
# Run:  11 of 20 k:  45 Time elapsed:  29259.2
# Run:  11 of 20 k:  48 Time elapsed:  29299.3
# Run:  11 of 20 k:  51 Time elapsed:  29341.2
# Run:  11 of 20 k:  54 Time elapsed:  29383.7
# Run:  11 of 20 k:  57 Time elapsed:  29426.3
# Run:  11 of 20 k:  60 Time elapsed:  29469.2
# Run:  11 of 20 k:  63 Time elapsed:  29512.3
# Run:  11 of 20 k:  66 Time elapsed:  29555.8
# Run:  11 of 20 k:  69 Time elapsed:  29599.6
# Run:  11 of 20 k:  72 Time elapsed:  29646.8
# Run:  11 of 20 k:  75 Time elapsed:  29691.4
# Run:  11 of 20 k:  78 Time elapsed:  29736.2
# Run:  11 of 20 k:  81 Time elapsed:  29781.6
# Run:  11 of 20 k:  84 Time elapsed:  29827.5
# Run:  11 of 20 k:  87 Time elapsed:  29874.1
# Run:  11 of 20 k:  90 Time elapsed:  29920.9
# Run:  11 of 20 k:  93 Time elapsed:  29966.7
# Run:  11 of 20 k:  96 Time elapsed:  30036.0
# Run:  11 of 20 k:  99 Time elapsed:  30084.1
# Run:  11 of 20 k:  102 Time elapsed:  30157.0
# Run:  11 of 20 k:  105 Time elapsed:  30207.3
# Run:  11 of 20 k:  108 Time elapsed:  30283.8
# Run:  11 of 20 k:  111 Time elapsed:  30335.4
# Run:  11 of 20 k:  114 Time elapsed:  30413.9
# Run:  11 of 20 k:  117 Time elapsed:  30478.3
# Run:  11 of 20 k:  120 Time elapsed:  30531.6
# Run:  11 of 20 k:  123 Time elapsed:  30585.3
# Run:  11 of 20 k:  126 Time elapsed:  30639.5
# Run:  11 of 20 k:  129 Time elapsed:  30695.2
# Run:  11 of 20 k:  132 Time elapsed:  30752.9
# Run:  11 of 20 k:  135 Time elapsed:  30811.4
# Run:  11 of 20 k:  138 Time elapsed:  30870.9
# Run:  11 of 20 k:  141 Time elapsed:  30931.1
# Run:  11 of 20 k:  144 Time elapsed:  30992.2
# Run:  11 of 20 k:  147 Time elapsed:  31053.8
# 12
# Generation successful. Time elapsed 31053.8
# Run:  12 of 20 k:  0 Time elapsed:  31162.2
# Run:  12 of 20 k:  3 Time elapsed:  31197.7
# Run:  12 of 20 k:  6 Time elapsed:  31233.3
# Run:  12 of 20 k:  9 Time elapsed:  31268.7
# Run:  12 of 20 k:  12 Time elapsed:  31302.9
# Run:  12 of 20 k:  15 Time elapsed:  31338.1
# Run:  12 of 20 k:  18 Time elapsed:  31373.4
# Run:  12 of 20 k:  21 Time elapsed:  31408.8
# Run:  12 of 20 k:  24 Time elapsed:  31444.1
# Run:  12 of 20 k:  27 Time elapsed:  31479.5
# Run:  12 of 20 k:  30 Time elapsed:  31515.1
# Run:  12 of 20 k:  33 Time elapsed:  31550.8
# Run:  12 of 20 k:  36 Time elapsed:  31587.5
# Run:  12 of 20 k:  39 Time elapsed:  31624.8
# Run:  12 of 20 k:  42 Time elapsed:  31664.4
# Run:  12 of 20 k:  45 Time elapsed:  31705.1
# Run:  12 of 20 k:  48 Time elapsed:  31746.1
# Run:  12 of 20 k:  51 Time elapsed:  31787.5
# Run:  12 of 20 k:  54 Time elapsed:  31829.5
# Run:  12 of 20 k:  57 Time elapsed:  31871.9
# Run:  12 of 20 k:  60 Time elapsed:  31915.0
# Run:  12 of 20 k:  63 Time elapsed:  31958.5
# Run:  12 of 20 k:  66 Time elapsed:  32003.2
# Run:  12 of 20 k:  69 Time elapsed:  32048.9
# Run:  12 of 20 k:  72 Time elapsed:  32095.2
# Run:  12 of 20 k:  75 Time elapsed:  32142.5
# Run:  12 of 20 k:  78 Time elapsed:  32191.2
# Run:  12 of 20 k:  81 Time elapsed:  32243.3
# Run:  12 of 20 k:  84 Time elapsed:  32293.6
# Run:  12 of 20 k:  87 Time elapsed:  32346.8
# Run:  12 of 20 k:  90 Time elapsed:  32402.8
# Run:  12 of 20 k:  93 Time elapsed:  32460.6
# Run:  12 of 20 k:  96 Time elapsed:  32521.8
# Run:  12 of 20 k:  99 Time elapsed:  32583.1
# Run:  12 of 20 k:  102 Time elapsed:  32646.4
# Run:  12 of 20 k:  105 Time elapsed:  32709.3
# Run:  12 of 20 k:  108 Time elapsed:  32772.3
# Run:  12 of 20 k:  111 Time elapsed:  32835.7
# Run:  12 of 20 k:  114 Time elapsed:  32900.7
# Run:  12 of 20 k:  117 Time elapsed:  32965.5
# Run:  12 of 20 k:  120 Time elapsed:  33029.5
# Run:  12 of 20 k:  123 Time elapsed:  33093.6
# Run:  12 of 20 k:  126 Time elapsed:  33158.0
# Run:  12 of 20 k:  129 Time elapsed:  33222.6
# Run:  12 of 20 k:  132 Time elapsed:  33287.7
# Run:  12 of 20 k:  135 Time elapsed:  33354.5
# Run:  12 of 20 k:  138 Time elapsed:  33420.7
# Run:  12 of 20 k:  141 Time elapsed:  33487.4
# Run:  12 of 20 k:  144 Time elapsed:  33554.0
# Run:  12 of 20 k:  147 Time elapsed:  33620.9
# 13
# Generation successful. Time elapsed 33621.0
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-18-afeb6637e9e8> in <module>
#      20         #candidates_and_votes, elimination_orders, va, candidates = setup()
#      21         if r%3==0:
# ---> 22             store.append(Cal_MR_K(r))
#      23             print("Run: ",j,"of",runs, "k: ",r, "Time elapsed: ", round(time.time()-START,1))
#      24         else:
#
# <ipython-input-18-afeb6637e9e8> in Cal_MR_K(col)
#      11         candidates_and_votes, elimination_orders, va, candidates = setup()
#      12         for order in elimination_orders:
# ---> 13             a,b = check_order(candidates_and_votes, order, col, va, gen_Candidates)
#      14             if a != "fail":
#      15                 MR += 1
#
# <ipython-input-5-40c80eb7b8f1> in check_order(candidates_and_votes, order, col_size, voting_array, candidates)
#      30                 else:
#      31                     # coalition was too small
# ---> 32                     remove_orders(eliminated_candidates)
#      33                     #print("Elimination order is impossible", order)
#      34                     return "fail","fail"
#
# <ipython-input-4-c66f3fc28f2c> in remove_orders(unsuccesful_start)
#       4     copy = elimination_orders.copy()
#       5     for i in copy:
# ----> 6         if i[0:k] == unsuccesful_start:
#       7             elimination_orders.remove(i)
#
# KeyboardInterrupt:

# %%
for k in range(13):
    csv_file = "Exports/C9V100/C9V100_"+str(k)+".csv"
    with open(csv_file, 'w',newline='') as csvfile:
        writer = csv.writer(csvfile)
        writer.writerow(stores[k])

# %%
for i in range(0,13):
    plt.plot(range(0,150),stores[i])    
plt.ylabel("$MR$ rate")
plt.xlabel("$\mathcal{K}$ (coalition size)")
plt.title("Ratio of possible elimination orders in which $c^*$ wins")
plt.show()

# %% [markdown]
# # Varying $\mathcal{V}$

# %% [markdown]
# Initial test of varying $\mathcal{K}$ to see what a reasonable coalition size might be, aiming for $MR=0.5$.

# %%
# Out:
# Generation successful. Time elapsed 0.6

# %%
#Successively pop elements from the voter-list, gen_Ranking 

K=60
runs=20
START = time.time()

for i in range(runs):
    stores = []

    gen_Ranking, gen_Candidates = spatialGeneration.returnRankings(7,10000)
    print("Generation",i," successful. Time elapsed",round(time.time()-START,1))

    num_voters = len(gen_Ranking)


    store = []

    for k in range(0,int(num_voters*0.9)):
        gen_Ranking.pop(0)
        if k%300==0:
            def Cal_MR_K(col):
                MR = 0
                candidates_and_votes, elimination_orders, va, candidates = setup()
                for order in elimination_orders:
                    a,b = check_order(candidates_and_votes, order, col, va, gen_Candidates)
                    if a != "fail":
                        MR += 1
                return MR/(math.factorial(len(gen_Candidates)-1))
            store.append(Cal_MR_K(K))
            print("Run: ",k,"of",int(num_voters*0.9), "Time elapsed: ", round(time.time()-START,1))
        else:
            store.append(store[-1])

    
    store.reverse
    plt.plot(range(int(num_voters*0.1),num_voters),store[::-1])#reverse array so V and MR line up, as we popped going backwards
    stores.append(store)
plt.ylabel("$MR$ rate")
plt.xlabel("$|\mathcal{V}|$ (number of votes)")
plt.title("Ratio of possible elimination orders in which $c^*$ wins")
plt.show()
# Out:
# Generation 0  successful. Time elapsed 5.4
# Run:  0 of 9000 Time elapsed:  54.3
# Run:  30 of 9000 Time elapsed:  104.1
# Run:  60 of 9000 Time elapsed:  152.9
# Run:  90 of 9000 Time elapsed:  201.5
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-49-37d66ca7c89e> in <module>
#      27                         MR += 1
#      28                 return MR/(math.factorial(len(gen_Candidates)-1))
# ---> 29             store.append(Cal_MR_K(K))
#      30             print("Run: ",k,"of",int(num_voters*0.9), "Time elapsed: ", round(time.time()-START,1))
#      31         else:
#
# <ipython-input-49-37d66ca7c89e> in Cal_MR_K(col)
#      23                 candidates_and_votes, elimination_orders, va, candidates = setup()
#      24                 for order in elimination_orders:
# ---> 25                     a,b = check_order(candidates_and_votes, order, col, va, gen_Candidates)
#      26                     if a != "fail":
#      27                         MR += 1
#
# <ipython-input-5-40c80eb7b8f1> in check_order(candidates_and_votes, order, col_size, voting_array, candidates)
#       1 def check_order(candidates_and_votes, order, col_size, voting_array, candidates):
#       2     coalition_size = copy.deepcopy(col_size)
# ----> 3     voting_array_c = copy.deepcopy(voting_array)
#       4     #print("HERE",candidates_and_votes)
#       5     coalition_votes = []
#
# ~\anaconda3\lib\copy.py in deepcopy(x, memo, _nil)
#     144     copier = _deepcopy_dispatch.get(cls)
#     145     if copier is not None:
# --> 146         y = copier(x, memo)
#     147     else:
#     148         if issubclass(cls, type):
#
# ~\anaconda3\lib\copy.py in _deepcopy_list(x, memo, deepcopy)
#     203     append = y.append
#     204     for a in x:
# --> 205         append(deepcopy(a, memo))
#     206     return y
#     207 d[list] = _deepcopy_list
#
# ~\anaconda3\lib\copy.py in deepcopy(x, memo, _nil)
#     144     copier = _deepcopy_dispatch.get(cls)
#     145     if copier is not None:
# --> 146         y = copier(x, memo)
#     147     else:
#     148         if issubclass(cls, type):
#
# ~\anaconda3\lib\copy.py in _deepcopy_dict(x, memo, deepcopy)
#     228     memo[id(x)] = y
#     229     for key, value in x.items():
# --> 230         y[deepcopy(key, memo)] = deepcopy(value, memo)
#     231     return y
#     232 d[dict] = _deepcopy_dict
#
# ~\anaconda3\lib\copy.py in deepcopy(x, memo, _nil)
#     140         return y
#     141
# --> 142     cls = type(x)
#     143
#     144     copier = _deepcopy_dispatch.get(cls)
#
# KeyboardInterrupt:
